# %%
# !pip install nltk

# %%
# !pip install zeyrek

# %%
# !pip install TurkishStemmer

# %%
import nltk
import zeyrek # https://github.com/obulat/zeyrek
from TurkishStemmer import TurkishStemmer # https://github.com/otuncelli/turkish-stemmer-python

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\enes2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
analyzer = zeyrek.MorphAnalyzer()

# %%
analyzer.lemmatize("benimkilerden")
# Out:
# [('benimkilerden', ['benimki'])]

# %%
stemmer = TurkishStemmer()

# %%
stemmer.stem("benimkilerden")
# Out:
# 'benimki'

# %%
cumle = "Dönülmez akşamın ufkundayım."

# %%
stemmer.stem(cumle)
# Out:
# 'Dönülmez akşamın ufkundayım.'

# %%
analyzer.lemmatize(cumle)
# Out:
# [('Dönülmez', ['dönmek']),
#  ('akşamın', ['akşam']),
#  ('ufkundayım', ['ufuk']),
#  ('.', ['.'])]

# %%
for kelime in cumle.split():
    print(stemmer.stem(kelime))
# Out:
# Dönülmez
# akşa
# ufkundayım.

# %%
import pandas as pd

# %%
# !pip install openpyxl

# %%
df = pd.read_excel("filmveriseti.xlsx") 
# https://www.kaggle.com/code/furkanyeter/content-based-recommendation-system-turkish-movie/data
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk

# %%
len(df)
# Out:
# 5261

# %%
df["tur"].unique()
# Out:
# array(["['Dram', 'Biyografik']", "['Animasyon', 'Aile', 'Macera']",
#        "['Fantastik', 'Macera']", "['Komedi']",
#        "['Aksiyon', 'Fantastik', 'Macera']",
#        "['Animasyon', 'Aile', 'Komedi']", "['Dram']",
#        "['Dram', 'Aksiyon']", "['Aksiyon', 'Macera', 'Fantastik']",
#        "['Aksiyon', 'Polisiye', 'Gerilim']",
#        "['Fantastik', 'Aksiyon', 'Macera']", "['Biyografik', 'Dram']",
#        "['Animasyon']", "['Bilimkurgu', 'Gerilim', 'Aksiyon']",
#        "['Dram', 'Romantik', 'Gerilim']",
#        "['Romantik', 'Dram', 'Erotik']",
#        "['Komedi', 'Aksiyon', 'Macera']", "['Macera', 'Aile']",
#        "['Aksiyon', 'Tarihi']", "['Bilimkurgu', 'Dram']", "['Aksiyon']",
#        "['Aksiyon', 'Fantastik']", "['Gerilim', 'Korku']",
#        "['Komedi', 'Romantik']", "['Dram', 'Romantik']",
#        "['Bilimkurgu', 'Gerilim']", "['Animasyon', 'Macera', 'Komedi']",
#        "['Komedi', 'Aksiyon', 'Bilimkurgu']",
#        "['Romantik', 'Fantastik', 'Dram']", "['Dram', 'Erotik']",
#        "['Gerilim', 'Dram']", "['Aksiyon', 'Gerilim']",
#        "['Fantastik', 'Macera', 'Aile']", "['Animasyon', 'Aile']",
#        "['Macera', 'Aksiyon']", "['Korku']", "['Gerilim']",
#        "['Macera', 'Aksiyon', 'Fantastik']",
#        "['Komedi', 'Fantastik', 'Aile', 'Macera']", "['Aile', 'Komedi']",
#        "['Animasyon', 'Aile', 'Fantastik', 'Komedi']",
#        "['Komedi', 'Dram']", "['Dram', 'Romantik', 'Erotik']",
#        "['Tarihi']", "['Animasyon', 'Komedi', 'Aile', 'Macera']",
#        "['Polisiye', 'Dram']", "['Animasyon', 'Macera']",
#        "['Dram', 'Gerilim']", "['Aksiyon', 'Polisiye']",
#        "['Romantik', 'Komedi']", "['Aksiyon', 'Dram', 'Biyografik']",
#        "['Dram', 'Tarihi']", "['Bilimkurgu', 'Korku', 'Gerilim']",
#        "['Gerilim', 'Fantastik']", "['Romantik', 'Dram']",
#        "['Gerilim', 'Aksiyon']", "['Aksiyon', 'Macera']", "['Erotik']",
#        "['Fantastik', 'Romantik']", "['Macera', 'Aile', 'Fantastik']",
#        "['Korku', 'Gerilim']", "['Bilimkurgu', 'Aksiyon']",
#        "['Polisiye', 'Dram', 'Komedi']", "['Dram', 'Komedi']",
#        "['Dramatik komedi']", "['Dram', 'Müzik']",
#        "['Aksiyon', 'Bilimkurgu']", "['Savaş filmi', 'Dram']",
#        "['Erotik', 'Dram', 'Romantik']",
#        "['Bilimkurgu', 'Romantik', 'Aksiyon']", "['Komedi', 'Aile']",
#        "['Komedi', 'Romantik', 'Erotik']",
#        "['Animasyon', 'Komedi', 'Aile']",
#        "['Animasyon', 'Fantastik', 'Aile']", "['Tarihi', 'Aksiyon']",
#        "['Aksiyon', 'Macera', 'Bilimkurgu']",
#        "['Gerilim', 'Polisiye', 'Dram']",
#        "['Bilimkurgu', 'Dram', 'Komedi']",
#        "['Animasyon', 'Aksiyon', 'Komedi', 'Aile']",
#        "['Aksiyon', 'Korku']", "['Gerilim', 'Polisiye', 'Erotik']",
#        "['Aksiyon', 'Macera', 'Dram', 'Tarihi', 'Savaş filmi']",
#        "['Savaş filmi', 'Dram', 'Aksiyon']",
#        "['Animasyon', 'Aile', 'Fantastik']", "['Aile']",
#        "['Fantastik', 'Aksiyon']",
#        "['Animasyon', 'Komedi', 'Macera', 'Aile']",
#        "['Gerilim', 'Dram', 'Aksiyon']", "['Aksiyon', 'Casusluk']",
#        "['Dram', 'Savaş filmi']",
#        "['Macera', 'Animasyon', 'Aile', 'Aksiyon', 'Komedi']",
#        "['Fantastik']", "['Fantastik', 'Aile']",
#        "['Fantastik', 'Aksiyon', 'Gerilim']", "['Dram', 'Aile']",
#        "['Komedi', 'Animasyon']",
#        "['Animasyon', 'Macera', 'Fantastik', 'Aile']",
#        "['Bilimkurgu', 'Macera']",
#        "['Bilimkurgu', 'Aksiyon', 'Fantastik']",
#        "['Animasyon', 'Aksiyon', 'Fantastik']",
#        "['Gerilim', 'Romantik', 'Dram']", "['Komedi', 'Dram', 'Aile']",
#        "['Bilimkurgu']", "['Fantastik', 'Polisiye']",
#        "['Dram', 'Macera', 'Romantik']",
#        "['Animasyon', 'Fantastik', 'Aile', 'Romantik', 'Müzikal']",
#        "['Aksiyon', 'Dram']", "['Dram', 'Macera']",
#        "['Dram', 'Bollywood']", "['Macera', 'Fantastik']",
#        "['Dram', 'Fantastik', 'Romantik']", "['Animasyon', 'Müzik']",
#        "['Gerilim', 'Dram', 'Korku']", "['Bollywood', 'Dram']",
#        "['Fantastik', 'Romantik', 'Macera', 'Dram']",
#        "['Komedi', 'Bollywood']", "['Dram', 'Biyografik', 'Komedi']",
#        "['Romantik', 'Dram', 'Komedi']",
#        "['Aksiyon', 'Gerilim', 'Casusluk']",
#        "['Macera', 'Aksiyon', 'Dram']",
#        "['Macera', 'Fantastik', 'Dram', 'Epik']",
#        "['Gerilim', 'Polisiye', 'Aksiyon']",
#        "['Bilimkurgu', 'Fantastik', 'Aksiyon']",
#        "['Dram', 'Gerilim', 'Erotik']",
#        "['Dram', 'Gerilim', 'Fantastik']", "['Western', 'Macera']",
#        "['Animasyon', 'Müzikal', 'Aile']",
#        "['Romantik', 'Fantastik', 'Macera']",
#        "['Tarihi', 'Dram', 'Savaş filmi', 'Aksiyon']",
#        "['Gerilim', 'Fantastik', 'Korku']", "['Dram', 'Bilimkurgu']",
#        "['Aksiyon', 'Gerilim', 'Bilimkurgu']",
#        "['Tarihi', 'Savaş filmi']", "['Dram', 'Polisiye']",
#        "['Animasyon', 'Macera', 'Bilimkurgu', 'Fantastik']",
#        "['Aksiyon', 'Dövüş', 'Dram', 'Biyografik']", "['Romantik']",
#        "['Macera', 'Dram']", "['Polisiye']",
#        "['Tarihi', 'Biyografik', 'Dram']",
#        "['Dramatik komedi', 'Komedi', 'Romantik']",
#        "['Bilimkurgu', 'Aksiyon', 'Gerilim']", "['Bilimkurgu', 'Komedi']",
#        "['Polisiye', 'Gerilim']",
#        "['Epik', 'Aksiyon', 'Savaş filmi', 'Tarihi']",
#        "['Animasyon', 'Aksiyon', 'Aile']", "['Polisiye', 'Komedi']",
#        "['Macera', 'Komedi']", "['Fantastik', 'Korku', 'Gerilim']",
#        "['Aksiyon', 'Casusluk', 'Komedi']",
#        "['Aksiyon', 'Savaş filmi', 'Dram']",
#        "['Komedi', 'Aksiyon', 'Fantastik']",
#        "['Gerilim', 'Korku', 'Fantastik']", "['Biyografik']",
#        "['Animasyon', 'Komedi']", "['Dram', 'Gerilim', 'Biyografik']",
#        "['Macera', 'Komedi', 'Fantastik']", "['Komedi', 'Aksiyon']",
#        "['Komedi', 'Fantastik', 'Dram']",
#        "['Dram', 'Bilimkurgu', 'Gerilim']", "['Macera', 'Dram', 'Aile']",
#        "['Western']", "['Aksiyon', 'Bilimkurgu', 'Gerilim']",
#        "['Aksiyon', 'Korku', 'Gerilim']",
#        "['Dram', 'Komedi', 'Romantik']",
#        "['Fantastik', 'Dram', 'Romantik']", "['Polisiye', 'Aksiyon']",
#        "['Dram', 'Gerilim', 'Macera', 'Biyografik']",
#        "['Aksiyon', 'Casusluk', 'Macera']", "['Komedi', 'Macera']",
#        "['Dram', 'Fantastik']", "['Aksiyon', 'Gerilim', 'Korku']",
#        "['Fantastik', 'Dram', 'Korku']",
#        "['Korku', 'Aksiyon', 'Gerilim']",
#        "['Aksiyon', 'Gerilim', 'Dram']",
#        "['Savaş filmi', 'Dram', 'Biyografik']",
#        "['Dram', 'Macera', 'Tarihi']", "['Animasyon', 'Macera', 'Aile']",
#        "['Gerilim', 'Romantik', 'Komedi']",
#        "['Fantastik', 'Aksiyon', 'Macera', 'Tarihi']",
#        "['Fantastik', 'Epik', 'Macera']", "['Gerilim', 'Biyografik']",
#        "['Fantastik', 'Bilimkurgu']",
#        "['Animasyon', 'Macera', 'Aile', 'Komedi']",
#        "['Bilimkurgu', 'Aksiyon', 'Romantik']", "['Erotik', 'Dram']",
#        "['Aksiyon', 'Korku', 'Bilimkurgu']",
#        "['Komedi', 'Aile', 'Fantastik']",
#        "['Fantastik', 'Romantik', 'Müzikal']",
#        "['Tarihi', 'Biyografik ', 'Savaş filmi', 'Romantik']",
#        "['Animasyon', 'Fantastik']", "['Biyografik', 'Müzik', 'Dram']",
#        "['Dramatik komedi', 'Müzik']", "['Macera', 'Bilimkurgu']",
#        "['Dram', 'Casusluk', 'Gerilim', 'Biyografik']",
#        "['Bilimkurgu', 'Aksiyon', 'Macera']",
#        "['Macera', 'Animasyon', 'Aile']",
#        "['Animasyon', 'Komedi', 'Aile', 'Fantastik']",
#        "['Dram', 'Tarihi', 'Biyografik']", "['Fantastik', 'Gerilim']",
#        "['Bilimkurgu', 'Bollywood']", "['Savaş filmi', 'Aksiyon']",
#        "['Komedi', 'Romantik', 'Fantastik']",
#        "['Bilimkurgu', 'Aksiyon', 'Dram']",
#        "['Dramatik komedi', 'Fantastik']",
#        "['Fantastik', 'Macera', 'Dram', 'Aile']", "['Tarihi', 'Dram']",
#        "['Komedi', 'Dram', 'Romantik']", "['Aksiyon', 'Dram', 'Gerilim']",
#        "['Korku', 'Komedi']", "['Gerilim', 'Romantik']",
#        "['Fantastik', 'Macera', 'Aksiyon']",
#        "['Macera', 'Dram', 'Biyografik']",
#        "['Macera', 'Dram', 'Gerilim']",
#        "['Animasyon', 'Komedi', 'Macera']", "['Biyografik', 'Bollywood']",
#        "['Bilimkurgu', 'Fantastik', 'Korku']",
#        "['Aksiyon', 'Fantastik', 'Epik']",
#        "['Gerilim', 'Aksiyon', 'Polisiye']", "['Fantastik', 'Korku']",
#        "['Macera', 'Bilimkurgu', 'Aksiyon']",
#        "['Animasyon', 'Komedi', 'Aksiyon']", "['Dövüş', 'Aksiyon']",
#        "['Dramatik komedi', 'Mahkeme']",
#        "['Aksiyon', 'Dram', 'Bilimkurgu']", "['Komedi', 'Polisiye']",
#        "['Macera', 'Aksiyon', 'Bilimkurgu']", "['Gerilim', 'Bilimkurgu']",
#        "['Fantastik', 'Macera', 'Korku']",
#        "['Macera', 'Fantastik', 'Aksiyon']", "['Gerilim', 'Casusluk']",
#        "['Korku', 'Fantastik', 'Bilimkurgu', 'Gerilim', 'Aksiyon']",
#        "['Bilimkurgu', 'Dram', 'Romantik']",
#        "['Dram', 'Tarihi', 'Savaş filmi']", "['Gerilim', 'Polisiye']",
#        "['Dram', 'Tarihi', 'Romantik']", "['Macera', 'Animasyon']",
#        "['Macera']", "['Animasyon', 'Aile', 'Macera', 'Bilimkurgu']",
#        "['Fantastik', 'Bilimkurgu', 'Aksiyon']",
#        "['Gerilim', 'Dram', 'Western']",
#        "['Dramatik komedi', 'Romantik']",
#        "['Dram', 'Romantik', 'Bilimkurgu']", "['Gerilim', 'Savaş filmi']",
#        "['Aksiyon', 'Komedi']", "['Biyografik', 'Savaş filmi', 'Dram']",
#        "['Bilimkurgu', 'Romantik', 'Gerilim']",
#        "['Animasyon', 'Aksiyon']",
#        "['Savaş filmi', 'Biyografik ', 'Dram']",
#        "['Dram', 'Savaş filmi', 'Gerilim']",
#        "['Gerilim', 'Bilimkurgu', 'Korku']",
#        "['Animasyon', 'Komedi', 'Fantastik', 'Aile']",
#        "['Fantastik', 'Bilimkurgu', 'Dram']",
#        "['Epik', 'Aksiyon', 'Macera']",
#        "['Gerilim', 'Savaş filmi', 'Dram']",
#        "['Dram', 'Mahkeme', 'Gerilim']",
#        "['Gerilim', 'Dram', 'Polisiye']",
#        "['Dram', 'Korku', 'Bilimkurgu']",
#        "['Bilimkurgu', 'Macera', 'Aksiyon', 'Fantastik']",
#        "['Biyografik', 'Dram', 'Tarihi']",
#        "['Komedi', 'Aile', 'Romantik']",
#        "['Bilimkurgu', 'Gerilim', 'Dram']",
#        "['Dram', 'Macera', 'Komedi']",
#        "['Savaş filmi', 'Gerilim', 'Dram']",
#        "['Savaş filmi', 'Tarihi', 'Dram']",
#        "['Animasyon', 'Macera', 'Müzik']",
#        "['Aksiyon', 'Fantastik', 'Bilimkurgu']",
#        "['Romantik', 'Komedi', 'Fantastik']",
#        "['Komedi', 'Fantastik', 'Aile']",
#        "['Aksiyon', 'Fantastik', 'Gerilim']",
#        "['Dramatik komedi', 'Tarihi']", "['Aksiyon', 'Dram', 'Romantik']",
#        "['Macera', 'Fantastik', 'Bilimkurgu']",
#        "['Macera', 'Bilimkurgu', 'Gerilim']", "['Müzikal', 'Romantik']",
#        "['Komedi', 'Animasyon', 'Aile']",
#        "['Biyografik', 'Tarihi', 'Dram']",
#        "['Gerilim', 'Aksiyon', 'Dram']",
#        "['Dramatik komedi', 'Biyografik']", "['Aksiyon', 'Savaş filmi']",
#        "['Dram', 'Polisiye', 'Gerilim']",
#        "['Animasyon', 'Fantastik', 'Komedi']",
#        "['Animasyon', 'Aksiyon', 'Komedi', 'Aile', 'Macera']",
#        "['Aksiyon', 'Bollywood']", "['Polisiye', 'Aksiyon', 'Dram']",
#        "['Korku', 'Gerilim', 'Bilimkurgu']",
#        "['Animasyon', 'Aile', 'Macera', 'Komedi']", "['Savaş filmi']",
#        "['Komedi', 'Macera', 'Dram']", "['Komedi', 'Fantastik']",
#        "['Aksiyon', 'Macera', 'Gerilim', 'Bilimkurgu']",
#        "['Romantik', 'Dram', 'Fantastik']",
#        "['Macera', 'Fantastik', 'Aile']",
#        "['Fantastik', 'Dram', 'Bilimkurgu']", "['Gerilim', 'Macera']",
#        "['Animasyon', 'Macera', 'Komedi', 'Aile']",
#        "['Aksiyon', 'Bilimkurgu', 'Macera']",
#        "['Macera', 'Aksiyon', 'Aile', 'Fantastik']",
#        "['Bilimkurgu', 'Korku']", "['Dram', 'Komedi', 'Biyografik']",
#        "['Aile', 'Fantastik']",
#        "['Bilimkurgu', 'Romantik', 'Fantastik', 'Dram']",
#        "['Dövüş', 'Aksiyon', 'Dram', 'Aile']", "['Fantastik', 'Komedi']",
#        "['Macera', 'Dram', 'Tarihi']",
#        "['Aksiyon', 'Komedi', 'Fantastik']",
#        "['Bilimkurgu', 'Korku', 'Aksiyon']",
#        "['Tarihi', 'Macera', 'Savaş filmi']",
#        "['Bilimkurgu', 'Macera', 'Dram']",
#        "['Aksiyon', 'Macera', 'Dram']", "['Macera', 'Aksiyon', 'Komedi']",
#        "['Gerilim', 'Aksiyon', 'Komedi']",
#        "['Dram', 'Savaş filmi', 'Gerilim', 'Aksiyon']",
#        "['Polisiye', 'Bilimkurgu', 'Aksiyon']",
#        "['Gerilim', 'Dram', 'Tarihi']",
#        "['Western', 'Aksiyon', 'Macera']",
#        "['Korku', 'Fantastik', 'Gerilim']",
#        "['Aksiyon', 'Fantastik', 'Korku']",
#        "['Aksiyon', 'Macera', 'Bilimkurgu', 'Gerilim']",
#        "['Aksiyon', 'Gerilim', 'Polisiye']", "['Western', 'Aksiyon']",
#        "['Gerilim', 'Aksiyon', 'Mahkeme']",
#        "['Dramatik komedi', 'Gerilim']",
#        "['Animasyon', 'Macera', 'Fantastik', 'Komedi']",
#        "['Müzikal', 'Romantik', 'Dram']",
#        "['Bilimkurgu', 'Macera', 'Aksiyon']", "['Biyografik', 'Gerilim']",
#        "['Korku', 'Dram']", "['Dram', 'Polisiye', 'Romantik', 'Gerilim']",
#        "['Animasyon', 'Komedi', 'Aksiyon', 'Fantastik']",
#        "['Fantastik', 'Macera', 'Dram']",
#        "['Bilimkurgu', 'Fantastik', 'Dram']",
#        "['Aksiyon', 'Macera', 'Dövüş', 'Gerilim']", "['Korku', 'Macera']",
#        "['Tarihi', 'Gerilim', 'Savaş filmi']", "['Komedi', 'Korku']",
#        "['Dram', 'Aksiyon', 'Gerilim']",
#        "['Macera', 'Dram', 'Fantastik']",
#        "['Savaş filmi', 'Aksiyon', 'Romantik']",
#        "['Aksiyon', 'Macera', 'Fantastik', 'Bilimkurgu']",
#        "['Aksiyon', 'Macera', 'Bilimkurgu', 'Fantastik']",
#        "['Dram', 'Gerilim', 'Tarihi']",
#        "['Fantastik', 'Gerilim', 'Dram']",
#        "['Bilimkurgu', 'Gerilim', 'Macera']", "['Western', 'Korku']",
#        "['Korku', 'Gerilim', 'Fantastik', 'Bilimkurgu']",
#        "['Fantastik', 'Aksiyon', 'Korku']",
#        "['Dramatik komedi', 'Aile', 'Romantik']",
#        "['Dram', 'Romantik', 'Biyografik']",
#        "['Korku', 'Gerilim', 'Dram']", "['Macera', 'Biyografik']",
#        "['Müzikal', 'Gerilim', 'Korku', 'Dram']",
#        "['Müzikal', 'Dram', 'Polisiye']",
#        "['Fantastik', 'Macera', 'Dram', 'Bilimkurgu', 'Aksiyon']",
#        "['Gerilim', 'Dram', 'Bilimkurgu']",
#        "['Korku', 'Gerilim', 'Fantastik']",
#        "['Aksiyon', 'Macera', 'Gerilim']",
#        "['Dram', 'Romantik', 'Fantastik']",
#        "['Gerilim', 'Aksiyon', 'Korku']",
#        "['Bilimkurgu', 'Aile', 'Macera']",
#        "['Fantastik', 'Gerilim', 'Bilimkurgu']",
#        "['Macera', 'Aksiyon', 'Polisiye']",
#        "['Mahkeme', 'Gerilim', 'Komedi']", "['Aile', 'Macera', 'Komedi']",
#        "['Komedi', 'Macera', 'Aile']", "['Aile', 'Macera']",
#        "['Macera', 'Komedi', 'Bilimkurgu']",
#        "['Romantik', 'Dramatik komedi']",
#        "['Macera', 'Aksiyon', 'Romantik']",
#        "['Polisiye', 'Dram', 'Gerilim']", "['Dram', 'Aksiyon', 'Tarihi']",
#        "['Polisiye', 'Biyografik', 'Dram']",
#        "['Komedi', 'Romantik', 'Korku']",
#        "['Aksiyon', 'Gerilim', 'Romantik']",
#        "['Biyografik', 'Mahkeme', 'Dram', 'Macera']",
#        "['Aksiyon', 'Komedi', 'Casusluk', 'Romantik']",
#        "['Fantastik', 'Dram']", "['Macera', 'Aile', 'Bilimkurgu']",
#        "['Aksiyon', 'Gerilim', 'Macera']", "['Animasyon', 'Biyografik']",
#        "['Animasyon', 'Aile', 'Müzikal']",
#        "['Fantastik', 'Macera', 'Bilimkurgu', 'Aksiyon']",
#        "['Biyografik', 'Romantik']", "['Macera', 'Aksiyon', 'Epik']",
#        "['Animasyon', 'Komedi', 'Müzik']",
#        "['Animasyon', 'Aile', 'Romantik', 'Müzik']",
#        "['Bilimkurgu', 'Korku', 'Dram']",
#        "['Aksiyon', 'Komedi', 'Macera']",
#        "['Dram', 'Biyografik ', 'Romantik']",
#        "['Dram', 'Biyografik', 'Tarihi']",
#        "['Animasyon', 'Macera', 'Komedi', 'Aile', 'Fantastik']",
#        "['Macera', 'Bilimkurgu', 'Savaş filmi']",
#        "['Savaş filmi', 'Romantik']",
#        "['Fantastik', 'Bilimkurgu', 'Gerilim', 'Aksiyon']",
#        "['Korku', 'Dram', 'Gerilim']", "['Komedi', 'Erotik']",
#        "['Polisiye', 'Gerilim', 'Aksiyon']",
#        "['Korku', 'Dram', 'Fantastik']", "['Polisiye', 'Biyografik']",
#        "['Aksiyon', 'Gerilim', 'Polisiye', 'Macera']",
#        "['Korku', 'Fantastik']", "['Aksiyon', 'Macera', 'Komedi']",
#        "['Biyografik', 'Tarihi']", "['Komedi', 'Dram', 'Fantastik']",
#        "['Dram', 'Romantik', 'Müzikal']",
#        "['Animasyon', 'Komedi', 'Fantastik']",
#        "['Komedi', 'Bilimkurgu', 'Aksiyon']", "['Macera', 'Gerilim']",
#        "['Komedi', 'Dram', 'Savaş filmi', 'Dramatik komedi']",
#        "['Dram', 'Aksiyon', 'Polisiye']",
#        "['Polisiye', 'Gerilim', 'Dram']",
#        "['Romantik', 'Komedi', 'Dram']", "['Korku', 'Bilimkurgu']",
#        "['Animasyon', 'Aile', 'Komedi', 'Fantastik']",
#        "['Aksiyon', 'Bilimkurgu', 'Komedi']",
#        "['Aksiyon', 'Dram', 'Savaş filmi']",
#        "['Tarihi', 'Dram', 'Romantik']",
#        "['Fantastik', 'Komedi', 'Korku']",
#        "['Komedi', 'Fantastik', 'Romantik']",
#        "['Macera', 'Dram', 'Gerilim', 'Polisiye']",
#        "['Tarihi', 'Dram', 'Macera']",
#        "['Bilimkurgu', 'Macera', 'Fantastik']", "['Casusluk', 'Gerilim']",
#        "['Dövüş', 'Aksiyon', 'Fantastik']",
#        "['Animasyon ', 'Komedi', 'Aile']",
#        "['Macera', 'Korku', 'Bilimkurgu']",
#        "['Dramatik komedi', 'Aksiyon']",
#        "['Korku', 'Aksiyon', 'Fantastik']",
#        "['Animasyon', 'Müzik', 'Aile']",
#        "['Gerilim', 'Dram', 'Polisiye', 'Biyografik']",
#        "['Gerilim', 'Korku', 'Dram']",
#        "['Bilimkurgu', 'Dram', 'Macera', 'Romantik']",
#        "['Gerilim', 'Macera', 'Korku']", "['Dram', 'Macera', 'Aile']",
#        "['Dram', 'Macera', 'Gerilim']", "['Casusluk', 'Aksiyon']",
#        "['Aksiyon', 'Dövüş', 'Biyografik']",
#        "['Dramatik komedi', 'Fantastik', 'Dram', 'Komedi']",
#        "['Fantastik', 'Romantik', 'Aksiyon']",
#        "['Macera', 'Aile', 'Dram']",
#        "['Dramatik komedi', 'Dram', 'Komedi']",
#        "['Savaş filmi', 'Romantik', 'Gerilim']",
#        "['Macera', 'Tarihi', 'Fantastik']",
#        "['Fantastik', 'Gerilim', 'Aksiyon']",
#        "['Macera', 'Komedi', 'Aksiyon']", "['Tarihi', 'Biyografik']",
#        "['Biyografik', 'Gerilim', 'Polisiye']",
#        "['Fantastik', 'Aksiyon', 'Bilimkurgu']",
#        "['Dram', 'Fantastik', 'Korku']", "['Komedi', 'Romantik', 'Dram']",
#        "['Polisiye', 'Korku']",
#        "['Animasyon', 'Dram', 'Tarihi', 'Biyografik']",
#        "['Tarihi', 'Gerilim']", "['Dram', 'Korku', 'Gerilim']",
#        "['Müzik', 'Dram']", "['Western', 'Dram']",
#        "['Dram', 'Müzik', 'Romantik']", "['Dram', 'Gerilim', 'Polisiye']",
#        "['Animasyon', 'Macera', 'Fantastik', 'Müzikal']",
#        "['Dram', 'Aksiyon', 'Western']",
#        "['Casusluk', 'Gerilim', 'Aksiyon']",
#        "['Aksiyon', 'Dram', 'Polisiye', 'Romantik']",
#        "['Savaş filmi', 'Aksiyon', 'Dram']",
#        "['Dram', 'Romantik', 'Macera']",
#        "['Romantik', 'Bilimkurgu', 'Dram']",
#        "['Casusluk', 'Aksiyon', 'Gerilim']", "['Polisiye', 'Romantik']",
#        "['Dram', 'Tarihi', 'Gerilim']", "['Dram', 'Romantik', 'Komedi']",
#        "['Bilimkurgu', 'Fantastik']", "['Polisiye', 'Dram', 'Aksiyon']",
#        "['Dramatik komedi', 'Müzik', 'Romantik']",
#        "['Fantastik', 'Komedi', 'Romantik']",
#        "['Western', 'Macera', 'Dram']", "['Aile', 'Komedi', 'Animasyon']",
#        "['Macera', 'Dram', 'Aksiyon']", "['Animasyon', 'Gerilim']",
#        "['Macera', 'Animasyon', 'Aksiyon', 'Aile']",
#        "['Gerilim', 'Romantik', 'Tarihi']", "['Aksiyon', 'Dövüş']",
#        "['Romantik', 'Bilimkurgu', 'Komedi', 'Dram']",
#        "['Dramatik komedi', 'Biyografik', 'Dram']",
#        "['Bollywood', 'Tarihi']",
#        "['Macera', 'Aksiyon', 'Korku', 'Gerilim']",
#        "['Fantastik', 'Macera', 'Komedi', 'Bilimkurgu']",
#        "['Dramatik komedi', 'Macera']",
#        "['Aksiyon', 'Komedi', 'Dram', 'Bilimkurgu']",
#        "['Dram', 'Aksiyon', 'Macera']", "['Tarihi', 'Epik']",
#        "['Animasyon ', 'Fantastik', 'Macera']",
#        "['Macera', 'Bilimkurgu', 'Dram']",
#        "['Western', 'Aksiyon', 'Gerilim', 'Polisiye']",
#        "['Animasyon', 'Dram', 'Aile']",
#        "['Fantastik', 'Dramatik komedi']",
#        "['Dram', 'Gerilim', 'Savaş filmi']",
#        "['Dramatik komedi', 'Dram', 'Aile']",
#        "['Animasyon', 'Macera', 'Aile', 'Fantastik']",
#        "['Animasyon', 'Fantastik', 'Macera', 'Aile']",
#        "['Dramatik komedi', 'Polisiye']",
#        "['Komedi', 'Korku', 'Aksiyon']", "['Gerilim', 'Tarihi', 'Dram']",
#        "['Korku', 'Fantastik', 'Dram']",
#        "['Gerilim', 'Erotik', 'Polisiye']", "['Bilimkurgu', 'Romantik']",
#        "['Aksiyon', 'Dram', 'Polisiye']",
#        "['Gerilim', 'Korku', 'Polisiye']", "['Biyografik ', 'Dram']",
#        "['Animasyon', 'Macera', 'Fantastik', 'Bilimkurgu']",
#        "['Dram', 'Biyografik', 'Romantik']",
#        "['Tarihi', 'Savaş filmi', 'Romantik', 'Biyografik']",
#        "['Fantastik', 'Animasyon', 'Müzikal']",
#        "['Komedi', 'Aksiyon', 'Romantik']", "['Komedi', 'Aile', 'Dram']",
#        "['Dramatik komedi', 'Bollywood']",
#        "['Tarihi', 'Aksiyon', 'Dram']", "['Aksiyon', 'Macera', 'Tarihi']",
#        "['Aksiyon', 'Casusluk', 'Gerilim']",
#        "['Biyografik', 'Savaş filmi']", "['Dram', 'Gerilim', 'Romantik']",
#        "['Bilimkurgu', 'Dram', 'Aksiyon']",
#        "['Polisiye', 'Dram', 'Romantik']",
#        "['Bilimkurgu', 'Macera', 'Komedi']",
#        "['Aksiyon', 'Bilimkurgu', 'Fantastik']",
#        "['Gerilim', 'Polisiye', 'Komedi']",
#        "['Korku', 'Bilimkurgu', 'Fantastik']",
#        "['Dram', 'Aile', 'Fantastik']",
#        "['Aksiyon', 'Macera', 'Polisiye']",
#        "['Tarihi', 'Dram', 'Gerilim']",
#        "['Dram', 'Savaş filmi', 'Romantik']",
#        "['Aksiyon', 'Macera', 'Fantastik', 'Gerilim']",
#        "['Dram', 'Mahkeme']", "['Korku', 'Macera', 'Dram', 'Gerilim']",
#        "['Animasyon', 'Dram', 'Savaş filmi']",
#        "['Aksiyon', 'Komedi', 'Polisiye']",
#        "['Bilimkurgu', 'Komedi', 'Macera']",
#        "['Korku', 'Dram', 'Romantik']",
#        "['Western', 'Biyografik', 'Dram']",
#        "['Romantik', 'Aile', 'Dram']", "['Animasyon ', 'Macera', 'Aile']",
#        "['Bilimkurgu', 'Korku', 'Aksiyon', 'Gerilim']",
#        "['Dram', 'Animasyon']", "['Dram', 'Müzikal']",
#        "['Aksiyon', 'Polisiye', 'Dram']",
#        "['Animasyon', 'Macera', 'Fantastik']",
#        "['Komedi', 'Polisiye', 'Romantik']", "['Aile', 'Dram']",
#        "['Bilimkurgu', 'Aksiyon', 'Korku']", "['Animasyon ', 'Aile']",
#        "['Experimental']", "['Komedi', 'Fantastik', 'Macera']",
#        "['Macera', 'Aksiyon', 'Tarihi']",
#        "['Komedi', 'Aile', 'Animasyon']", "['Dramatik komedi', 'Dram']",
#        "['Dram', 'Gerilim', 'Mahkeme']", "['Dram', 'Romantik', 'Müzik']",
#        "['Komedi', 'Polisiye', 'Aksiyon']", "['Aksiyon', 'Dram', 'Aile']",
#        "['Dövüş', 'Aksiyon', 'Dram']",
#        "['Korku', 'Bilimkurgu', 'Gerilim']",
#        "['Komedi', 'Aile', 'Macera']",
#        "['Gerilim', 'Fantastik', 'Polisiye']",
#        "['Aksiyon', 'Macera', 'Western']",
#        "['Macera', 'Dram', 'Polisiye']",
#        "['Dram', 'Savaş filmi', 'Tarihi', 'Romantik']",
#        "['Bilimkurgu', 'Gerilim', 'Fantastik']",
#        "['Aksiyon', 'Macera', 'Romantik']", "['Müzikal', 'Fantastik']",
#        "['Aksiyon', 'Komedi', 'Macera', 'Aile']",
#        "['Fantastik', 'Animasyon', 'Macera']",
#        "['Animasyon', 'Macera', 'Dram', 'Aile']",
#        "['Dram', 'Komedi', 'Polisiye']",
#        "['Komedi', 'Macera', 'Fantastik']",
#        "['Aksiyon', 'Dram', 'Komedi']",
#        "['Casusluk', 'Aksiyon', 'Komedi']",
#        "['Aksiyon', 'Macera', 'Biyografik']", "['Komedi', 'Müzikal']",
#        "['Polisiye', 'Dram', 'Korku']",
#        "['Animasyon', 'Fantastik', 'Macera']", "['Animasyon ', 'Dram']",
#        "['Bilimkurgu', 'Aksiyon', 'Komedi']",
#        "['Dram', 'Korku', 'Romantik']", "['Fantastik', 'Komedi', 'Dram']",
#        "['Fantastik', 'Dram', 'Gerilim']", "['Korku', 'Aksiyon']",
#        "['Animasyon', 'Macera', 'Dram']",
#        "['Fantastik', 'Müzikal', 'Macera']",
#        "['Macera', 'Tarihi', 'Romantik']",
#        "['Fantastik', 'Komedi', 'Aile']", "['Gerilim', 'Komedi']",
#        "['Komedi', 'Casusluk']", "['Dramatik komedi', 'Aile']",
#        "['Dram', 'Romantik', 'Gerilim', 'Erotik']",
#        "['Western', 'Macera', 'Komedi']",
#        "['Biyografik', 'Komedi', 'Dram']",
#        "['Korku', 'Gerilim', 'Aksiyon', 'Fantastik', 'Komedi']",
#        "['Bilimkurgu', 'Dram', 'Gerilim']", "['Müzik', 'Romantik']",
#        "['Macera', 'Korku', 'Gerilim']",
#        "['Aksiyon', 'Komedi', 'Macera', 'Polisiye']",
#        "['Tarihi', 'Polisiye']", "['Biyografik', 'Dram', 'Macera']",
#        "['Dram', 'Korku']", "['Gerilim', 'Dram', 'Erotik']",
#        "['Macera', 'Aksiyon', 'Fantastik', 'Gerilim']",
#        "['Savaş filmi', 'Dram', 'Tarihi']",
#        "['Polisiye', 'Gerilim', 'Romantik']",
#        "['Komedi', 'Polisiye', 'Gerilim']",
#        "['Macera', 'Korku', 'Tarihi']", "['Romantik', 'Gerilim']",
#        "['Animasyon', 'Müzikal', 'Romantik']",
#        "['Aksiyon', 'Dram', 'Dövüş']",
#        "['Savaş filmi', 'Dram', 'Polisiye', 'Tarihi']",
#        "['Müzikal', 'Dramatik komedi']",
#        "['Polisiye', 'Gerilim', 'Dram', 'Erotik']",
#        "['Aksiyon', 'Gerilim', 'Mahkeme']", "['Komedi', 'Müzik']",
#        "['Dram', 'Tarihi', 'Müzik']", "['Dram', 'Animasyon', 'Romantik']",
#        "['Dram', 'Gerilim', 'Aksiyon']",
#        "['Korku', 'Gerilim', 'Aksiyon']", "['Dram', 'Dramatik komedi']",
#        "['Bilimkurgu', 'Animasyon']", "['Müzik', 'Biyografik', 'Dram']",
#        "['Aile', 'Macera', 'Fantastik']",
#        "['Gerilim', 'Bilimkurgu', 'Fantastik']",
#        "['Fantastik', 'Aile', 'Macera']",
#        "['Gerilim', 'Dram', 'Romantik']",
#        "['Tarihi', 'Dram', 'Biyografik']", "['Concert', 'Müzik']",
#        "['Aksiyon', 'Polisiye', 'Mahkeme']",
#        "['Dram', 'Biyografik', 'Müzik', 'Romantik']",
#        "['Dram', 'Komedi', 'Gerilim']", "['Macera', 'Polisiye']",
#        "['Dövüş', 'Aksiyon', 'Gerilim']",
#        "['Animasyon ', 'Macera', 'Komedi']",
#        "['Polisiye', 'Dramatik komedi']",
#        "['Müzikal', 'Komedi', 'Romantik']",
#        "['Biyografik ', 'Dram', 'Müzik', 'Romantik']",
#        "['Dram', 'Fantastik', 'Gerilim']",
#        "['Korku', 'Polisiye', 'Gerilim']",
#        "['Biyografik', 'Dram', 'Müzik']",
#        "['Komedi', 'Aksiyon', 'Polisiye']",
#        "['Romantik', 'Fantastik', 'Komedi']",
#        "['Bilimkurgu', 'Komedi', 'Romantik']",
#        "['Fantastik', 'Macera', 'Komedi']",
#        "['Biyografik', 'Dramatik komedi', 'Dram', 'Komedi']",
#        "['Aksiyon', 'Dramatik komedi']",
#        "['Western', 'Dram', 'Biyografik', 'Aksiyon']",
#        "['Animasyon', 'Aile', 'Macera', 'Tarihi']",
#        "['Biyografik', 'Gerilim', 'Aksiyon', 'Dram']",
#        "['Aksiyon', 'Gerilim', 'Dövüş']",
#        "['Biyografik', 'Dram', 'Romantik']",
#        "['Tarihi', 'Dramatik komedi']",
#        "['Polisiye', 'Aksiyon', 'Gerilim']",
#        "['Polisiye', 'Fantastik', 'Gerilim']",
#        "['Dramatik komedi', 'Macera', 'Biyografik']",
#        "['Dramatik komedi', 'Erotik', 'Romantik']",
#        "['Tarihi', 'Aksiyon', 'Macera']",
#        "['Macera', 'Aksiyon', 'Gerilim']",
#        "['Aksiyon', 'Polisiye', 'Komedi']",
#        "['Dram', 'Komedi', 'Fantastik', 'Romantik']",
#        "['Dram', 'Romantik', 'Tarihi']",
#        "['Fantastik', 'Romantik', 'Dram']",
#        "['Animasyon', 'Komedi', 'Bilimkurgu', 'Macera']",
#        "['Tarihi', 'Dram', 'Aksiyon']",
#        "['Aksiyon', 'Biyografik', 'Western']",
#        "['Polisiye', 'Dramatik komedi', 'Komedi', 'Gerilim']",
#        "['Biyografik', 'Macera']", "['Dram', 'Biyografik ', 'Tarihi']",
#        "['Komedi', 'Polisiye', 'Dram']",
#        "['Savaş filmi', 'Aksiyon', 'Tarihi']",
#        "['Komedi', 'Macera', 'Romantik']",
#        "['Gerilim', 'Aksiyon', 'Bilimkurgu']",
#        "['Aksiyon', 'Komedi', 'Bilimkurgu']",
#        "['Animasyon', 'Macera', 'Komedi', 'Aile', 'Bilimkurgu']",
#        "['Dram', 'Biyografik', 'Sport event']",
#        "['Komedi', 'Macera', 'Korku']", "['Polisiye', 'Macera']",
#        "['Komedi', 'Dram', 'Müzik']",
#        "['Tarihi', 'Dram', 'Aksiyon', 'Macera']",
#        "['Tarihi', 'Polisiye', 'Macera']",
#        "['Dövüş', 'Dram', 'Romantik']", "['Polisiye', 'Casusluk']",
#        "['Korku', 'Romantik', 'Gerilim']", "['Mahkeme', 'Gerilim']",
#        "['Komedi', 'Fantastik', 'Aksiyon', 'Macera']",
#        "['Fantastik', 'Aksiyon', 'Dram']",
#        "['Biyografik', 'Dövüş', 'Aksiyon']",
#        "['Komedi', 'Casusluk', 'Aksiyon']",
#        "['Korku', 'Komedi', 'Aksiyon']", "['Korku', 'Biyografik']",
#        "['Korku', 'Fantastik', 'Romantik']",
#        "['Gerilim', 'Korku', 'Polisiye', 'Dram']",
#        "['Komedi', 'Savaş filmi']",
#        "['Aksiyon', 'Macera', 'Tarihi', 'Fantastik']",
#        "['Müzik', 'Polisiye', 'Romantik', 'Dram']",
#        "['Romantik', 'Müzikal']", "['Biyografik ', 'Dram', 'Romantik']",
#        "['Animasyon ', 'Macera']",
#        "['Biyografik', 'Dram', 'Savaş filmi']",
#        "['Epik', 'Macera', 'Dram']", "['Müzikal']",
#        "['Savaş filmi', 'Dram', 'Gerilim']",
#        "['Dramatik komedi', 'Savaş filmi']",
#        "['Western', 'Tarihi', 'Aksiyon']", "['Dram', 'Casusluk']",
#        "['Müzikal', 'Dram', 'Aile', 'Romantik']",
#        "['Dram', 'Polisiye', 'Romantik']",
#        "['Western', 'Macera', 'Aksiyon']",
#        "['Savaş filmi', 'Romantik', 'Dram']",
#        "['Müzikal', 'Aile', 'Dram']", "['Western', 'Gerilim', 'Dram']",
#        "['Komedi', 'Tarihi', 'Erotik']",
#        "['Dram', 'Romantik', 'Dramatik komedi']",
#        "['Polisiye', 'Gerilim', 'Biyografik']",
#        "['Animasyon ', 'Komedi', 'Macera']",
#        "['Gerilim', 'Aksiyon', 'Dram', 'Savaş filmi']",
#        "['Dramatik komedi', 'Fantastik', 'Sport event']",
#        "['Macera', 'Savaş filmi']",
#        "['Dram', 'Biyografik', 'Savaş filmi']",
#        "['Komedi', 'Dram', 'Korku', 'Fantastik']",
#        "['Dram', 'Gerilim', 'Komedi']",
#        "['Macera', 'Dövüş', 'Fantastik', 'Aksiyon']",
#        "['Müzikal', 'Aile']", "['Aksiyon', 'Biyografik', 'Macera']",
#        "['Dram', 'Komedi', 'Müzikal']",
#        "['Savaş filmi', 'Dram', 'Tarihi', 'Aksiyon']",
#        "['Komedi', 'Animasyon', 'Macera']",
#        "['Tarihi', 'Aksiyon', 'Dram', 'Savaş filmi']",
#        "['Dram', 'Savaş filmi', 'Tarihi']",
#        "['Animasyon', 'Komedi', 'Aile', 'Bilimkurgu', 'Macera']",
#        "['Macera', 'Komedi', 'Dram', 'Aile']",
#        "['Aksiyon', 'Dram', 'Tarihi', 'Savaş filmi']",
#        "['Dram', 'Romantik', 'Savaş filmi']",
#        "['Biyografik', 'Polisiye']",
#        "['Aksiyon', 'Aile', 'Gerilim', 'Dramatik komedi']",
#        "['Tarihi', 'Macera']",
#        "['Komedi', 'Romantik', 'Macera', 'Polisiye']",
#        "['Animasyon', 'Komedi', 'Bilimkurgu']", "['Gerilim', 'Erotik']",
#        "['Animasyon', 'Bilimkurgu', 'Aksiyon', 'Dram']",
#        "['Dram', 'Komedi', 'Savaş filmi']",
#        "['Bilimkurgu', 'Western', 'Aksiyon', 'Macera']",
#        "['Biyografik', 'Müzikal']", "['Macera', 'Romantik', 'Dram']",
#        "['Animasyon', 'Aile', 'Komedi', 'Dram']", "['Dövüş', 'Dram']",
#        "['Komedi', 'Müzik', 'Romantik', 'Dram']",
#        "['Gerilim', 'Mahkeme']", "['Polisiye', 'Aksiyon', 'Komedi']",
#        "['Aksiyon', 'Korku', 'Gerilim', 'Komedi']",
#        "['Casusluk', 'Aksiyon', 'Macera']",
#        "['Komedi', 'Animasyon', 'Aile', 'Macera']",
#        "['Fantastik', 'Komedi', 'Bilimkurgu']",
#        "['Aksiyon', 'Bilimkurgu', 'Savaş filmi']",
#        "['Macera', 'Aile', 'Animasyon', 'Fantastik']",
#        "['Macera', 'Fantastik', 'Komedi']",
#        "['Macera', 'Komedi', 'Romantik']",
#        "['Biyografik ', 'Polisiye', 'Dram']",
#        "['Dram', 'Komedi', 'Fantastik']", "['Komedi', 'Gerilim']",
#        "['Korku', 'Gerilim', 'Macera']",
#        "['Dram', 'Romantik', 'Macera', 'Savaş filmi']",
#        "['Müzik', 'Komedi']", "['Biyografik ', 'Dram', 'Gerilim']",
#        "['Macera', 'Dram', 'Romantik']", "['Macera', 'Tarihi', 'Dram']",
#        "['Aksiyon', 'Romantik']", "['Fantastik', 'Korku', 'Müzik']",
#        "['Gerilim', 'Tarihi']",
#        "['Dramatik komedi', 'Tarihi', 'Romantik']",
#        "['Animasyon', 'Aksiyon', 'Macera']",
#        "['Biyografik', 'Dram', 'Komedi']",
#        "['Animasyon', 'Fantastik', 'Aile', 'Macera']",
#        "['Macera', 'Aksiyon', 'Dram', 'Savaş filmi']",
#        "['Bilimkurgu', 'Korku', 'Fantastik']",
#        "['Komedi', 'Bilimkurgu', 'Macera']", "['Aile', 'Animasyon']",
#        "['Dram', 'Experimental']", "['Animasyon ', 'Çizgi film']",
#        "['Animasyon ', 'Aile', 'Komedi']", "['Macera', 'Komedi', 'Dram']",
#        "['Macera', 'Western', 'Aksiyon']",
#        "['Aksiyon', 'Gerilim', 'Komedi']",
#        "['Animasyon ', 'Komedi', 'Müzikal']",
#        "['Gerilim', 'Polisiye', 'Aksiyon', 'Dram']",
#        "['Dramatik komedi', 'Müzikal']", "['Biyografik', 'Komedi']",
#        "['Fantastik', 'Aksiyon', 'Korku', 'Gerilim']",
#        "['Komedi', 'Animasyon ', 'Aile']", "['Tarihi', 'Romantik']",
#        "['Komedi', 'Bilimkurgu', 'Romantik', 'Müzik']",
#        "['Polisiye', 'Bilimkurgu', 'Dram']",
#        "['Aksiyon', 'Casusluk', 'Gerilim', 'Polisiye']",
#        "['Mahkeme', 'Dramatik komedi']",
#        "['Fantastik', 'Tarihi', 'Gerilim', 'Western']",
#        "['Macera', 'Tarihi']", "['Komedi', 'Dram', 'Savaş filmi']",
#        "['Komedi', 'Müzikal', 'Romantik']",
#        "['Macera', 'Gerilim', 'Aksiyon', 'Polisiye']",
#        "['Aile', 'Çizgi film']", "['Polisiye', 'Komedi', 'Romantik']",
#        "['Aksiyon', 'Bilimkurgu', 'Korku']",
#        "['Fantastik', 'Korku', 'Dram', 'Gerilim']",
#        "['Fantastik', 'Tarihi', 'Aksiyon']",
#        "['Dram', 'Polisiye', 'Komedi']",
#        "['Fantastik', 'Komedi', 'Aile', 'Macera']",
#        "['Dövüş', 'Aksiyon', 'Macera']", "['Western', 'Komedi']",
#        "['Müzik', 'Dram', 'Romantik']",
#        "['Aksiyon', 'Biyografik ', 'Dram']", "['Animasyon ', 'Komedi']",
#        "['Biyografik ', 'Tarihi']", "['Tarihi', 'Dram', 'Savaş filmi']",
#        "['Dramatik komedi', 'Dram', 'Komedi', 'Romantik']",
#        "['Gerilim', 'Biyografik ', 'Dram']",
#        "['Müzikal', 'Dram', 'Aile']", "['Dram', 'Komedi', 'Mahkeme']",
#        "['Animasyon', 'Bilimkurgu']",
#        "['Dram', 'Fantastik', 'Bilimkurgu']",
#        "['Savaş filmi', 'Dram', 'Aksiyon', 'Tarihi']",
#        "['Polisiye', 'Gerilim', 'Komedi']",
#        "['Komedi', 'Macera', 'Polisiye']", "['Aksiyon', 'Biyografik']",
#        "['Gerilim', 'Dram', 'Fantastik']",
#        "['Savaş filmi', 'Aksiyon', 'Macera', 'Dram', 'Romantik']",
#        "['Animasyon', 'Aksiyon', 'Bilimkurgu']",
#        "['Dram', 'Savaş filmi', 'Casusluk']",
#        "['Dramatik komedi', 'Gerilim', 'Romantik']",
#        "['Aksiyon', 'Komedi', 'Gerilim']",
#        "['Aksiyon', 'Polisiye', 'Bilimkurgu']",
#        "['Komedi', 'Fantastik', 'Bilimkurgu']",
#        "['Animasyon', 'Bilimkurgu', 'Macera']",
#        "['Western', 'Komedi', 'Aksiyon']",
#        "['Komedi', 'Müzikal', 'Aksiyon']",
#        "['Gerilim', 'Aksiyon', 'Macera', 'Polisiye', 'Dram']",
#        "['Casusluk', 'Romantik', 'Gerilim', 'Komedi']",
#        "['Romantik', 'Animasyon']", "['Korku', 'Komedi', 'Gerilim']",
#        "['Dram', 'Tarihi', 'Komedi']", "['Komedi', 'Romantik', 'Müzik']",
#        "['Müzik']", "['Aksiyon', 'Romantik', 'Gerilim']",
#        "['Casusluk', 'Macera', 'Komedi', 'Aksiyon']",
#        "['Komedi', 'Gerilim', 'Aksiyon', 'Polisiye']",
#        "['Animasyon', 'Macera', 'Komedi', 'Bilimkurgu', 'Aile']",
#        "['Dramatik komedi', 'Romantik', 'Dram']",
#        "['Müzikal', 'Fantastik', 'Aile']",
#        "['Gerilim', 'Fantastik', 'Aksiyon']",
#        "['Dramatik komedi', 'Fantastik', 'Biyografik']",
#        "['Bilimkurgu', 'Dram', 'Gerilim', 'Korku', 'Fantastik']",
#        "['Polisiye', 'Komedi', 'Aksiyon']",
#        "['Macera', 'Dramatik komedi', 'Aile']",
#        "['Aile', 'Macera', 'Animasyon']",
#        "['Dram', 'Biyografik', 'Polisiye']"], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5261 entries, 0 to 5260
# Data columns (total 7 columns):
# film adi            5261 non-null object
# ozet ve detaylar    5261 non-null object
# tur                 5261 non-null object
# oyuncular           5261 non-null object
# yonetmen            5261 non-null object
# vizyon tarihi       5261 non-null object
# sure                5261 non-null object
# dtypes: object(7)
# memory usage: 287.8+ KB

# %%
df.isna().sum()
# Out:
# film adi            0
# ozet ve detaylar    0
# tur                 0
# oyuncular           0
# yonetmen            0
# vizyon tarihi       0
# sure                0
# dtype: int64

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\enes2\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string
from nltk.corpus import stopwords

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
dolgular = stopwords.words("turkish")
dolgular
# Out:
# ['acaba',
#  'ama',
#  'aslında',
#  'az',
#  'bazı',
#  'belki',
#  'biri',
#  'birkaç',
#  'birşey',
#  'biz',
#  'bu',
#  'çok',
#  'çünkü',
#  'da',
#  'daha',
#  'de',
#  'defa',
#  'diye',
#  'eğer',
#  'en',
#  'gibi',
#  'hem',
#  'hep',
#  'hepsi',
#  'her',
#  'hiç',
#  'için',
#  'ile',
#  'ise',
#  'kez',
#  'ki',
#  'kim',
#  'mı',
#  'mu',
#  'mü',
#  'nasıl',
#  'ne',
#  'neden',
#  'nerde',
#  'nerede',
#  'nereye',
#  'niçin',
#  'niye',
#  'o',
#  'sanki',
#  'şey',
#  'siz',
#  'şu',
#  'tüm',
#  've',
#  'veya',
#  'ya',
#  'yani']

# %%
s = "Hey! Naber? İyilik, senden... Ben de iyiyim."
s = s.translate(str.maketrans ('', '', string.punctuation))

# %%
s
# Out:
# 'Hey Naber İyilik senden Ben de iyiyim'

# %%
analiz = analyzer.lemmatize(s)
analiz
# Out:
# [('Hey', ['hey']),
#  ('Naber', ['Naber']),
#  ('İyilik', ['iyi']),
#  ('senden', ['sen', 'se']),
#  ('Ben', ['ben']),
#  ('de', ['de', 'demek']),
#  ('iyiyim', ['iyi'])]

# %%
for el in analiz:
    print(el[1][-1])
# Out:
# hey
# Naber
# iyi
# se
# ben
# demek
# iyi

# %%
ornek = df.iloc[13]["ozet ve detaylar"]
ornek
# Out:
# "25 yaşına gelen insanların, yaşlanmayı durdurmak için var güçleriyle çalışmak zorunda olduğu bir gelecekte geçen filmde, zaman gerçekten para ve güç demek. Will Salas (Justin Timberlake), bir hata sonucu cinayetten hüküm giyer ve hapishaneden kurtulmak için tek şansı gerçek yüzünü gördüğü sistemi çökertmektir. Zira zamanın rahatlıkla satın alınabildiği bu sistemde zenginler sonsuza kadar genç kalarak yaşarken fakir ve güçsüz olan ise ölerek, elenir. Üstelik kendi yaşayamadıkları yıllar başkalarının hayatlarına eklenir. Güçs üz olanlar sadece bir gün daha hayatta kalabilmek için 'zaman' dilenir, ödünç alır hatta bazen zamanı çalar. Will Salas ise bütün bu yozlaşmış sisteme karşı baş kaldırır... Başrollerini son dönemde müzik çalışmalarına ara veren ve sinemaya yönelen Justin Timberlake ile yeni Scarlett Johansson olarak anılan Amanda Seyfried'in paylaştığı filmin yardımcı oyuncu kadrosunda ise Olivia Wilde, Alex Pettyfer, Cillian Murphy gibi isimler var.Daha önce Gattaca, S1m0ne ve Lord of War'ı hem yazıp hem yöneten, The Truman Show ve The Terminal gibi filmlerin senaryosunu kaleme alan Andrew Niccol'un son projesi büyük beklenti yaratıyor..."

# %%
ornek.translate(str.maketrans ('', '', string.punctuation))
# Out:
# '25 yaşına gelen insanların yaşlanmayı durdurmak için var güçleriyle çalışmak zorunda olduğu bir gelecekte geçen filmde zaman gerçekten para ve güç demek Will Salas Justin Timberlake bir hata sonucu cinayetten hüküm giyer ve hapishaneden kurtulmak için tek şansı gerçek yüzünü gördüğü sistemi çökertmektir Zira zamanın rahatlıkla satın alınabildiği bu sistemde zenginler sonsuza kadar genç kalarak yaşarken fakir ve güçsüz olan ise ölerek elenir Üstelik kendi yaşayamadıkları yıllar başkalarının hayatlarına eklenir Güçs üz olanlar sadece bir gün daha hayatta kalabilmek için zaman dilenir ödünç alır hatta bazen zamanı çalar Will Salas ise bütün bu yozlaşmış sisteme karşı baş kaldırır Başrollerini son dönemde müzik çalışmalarına ara veren ve sinemaya yönelen Justin Timberlake ile yeni Scarlett Johansson olarak anılan Amanda Seyfriedin paylaştığı filmin yardımcı oyuncu kadrosunda ise Olivia Wilde Alex Pettyfer Cillian Murphy gibi isimler varDaha önce Gattaca S1m0ne ve Lord of Warı hem yazıp hem yöneten The Truman Show ve The Terminal gibi filmlerin senaryosunu kaleme alan Andrew Niccolun son projesi büyük beklenti yaratıyor'

# %%
ornek = "film,çok güzel.tavsiye ederim."
ornek.translate(str.maketrans ('', '', string.punctuation))
# Out:
# 'filmçok güzeltavsiye ederim'

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r"\w+")
tokenizer.tokenize(ornek)
# Out:
# ['film', 'çok', 'güzel', 'tavsiye', 'ederim']

# %%
def clean_doc(doc, tok):
    """
    Args:
        doc (str): Köklerine ayrılacak doküman.
        tok (RegexpTokenizer): Instance of RegexpTokenizer from nltk.tokenize.

    Returns:
        [str]: List of lemmatized words from the doc argument without punctuation and stop words.
    
    Ex: clean_doc("film,çok güzel.tavsiye ederim.", tokenizer) -> ['film', 'güzel', 'tavsiye', 'eder']
    """
    tokens = tok.tokenize(doc) # doc'ları kelimelere ayır, noktalama işaretlerini çıkar
    clean_tokens = [tok for tok in tokens if tok not in dolgular] # stop word'leri ayıkla
    analiz = analyzer.lemmatize(" ".join(clean_tokens)) # token'ları ayıkla
    return [el[1][-1] for el in analiz] # temizlenmiş token'ları liste olarak döndür

# %%
tokenizer = RegexpTokenizer(r"\w+")
clean_doc(ornek, tokenizer)
# Out:
# ['film', 'güzel', 'tavsiye', 'eder']

# %%
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk

# %%
# bu işlem uzun sürebilir
# uzayda bir kavanozun kapağını açıp kapattığınızda ve kavanozu Ay'a doğru
# fırlattığınızda kavanoz içindeki boşluk hareket eder mi?
import ast

def extract_features(row, tokenizer):
    ozet = clean_doc(row["ozet ve detaylar"], tokenizer)
    tur = row["tur"]
    oyuncular = row["oyuncular"]
    yonetmen = row["yonetmen"]
    return ozet + ast.literal_eval(tur) + ast.literal_eval(oyuncular) + ast.literal_eval(yonetmen)

df["clean"] = df.apply(lambda row: extract_features(row, tokenizer), axis=1)

# %%
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                                                clean
# 0  [arabesk, unutulmayan, kadın, ses, o, Bergen, ...
# 1  [Çocuk, film, kirpi, Sonic, film, deva, halka,...
# 2  [karmak, büyü, Gellert, Grindelwald, büyü, dün...
# 3  [Aykut, enişte, 2, sevmek, kadın, evlilik, ari...
# 4  [Morbius, hastalık, deva, bulmak, Çalışır, bam...

# %%
import random
for i in range(2):
    rand_idx = random.randrange(len(df))
    ozet = df.iloc[rand_idx]["ozet ve detaylar"]
    print("Orijinal:")
    print(ozet + "\n")
    print("Temizlenmiş:")
    print(" ".join(df.iloc[rand_idx]["clean"]) + "\n")  
    print("/" * 50 + "\n")
# Out:
# Orijinal:
# Ali, okuduğu küçük şehirden ayrılarak Erasmus projesiyle yurtdışına çıkma hayalleri kuran bir mühendislik öğrencisidir. Aynı zamanda kendisini tanımaya çalışmakta, hayata dair sorular sormaktadır. Ali'nin bu sakin hayatı, bir türkü barda solistlik yapan Gülce’den hoşlanmasıyla beraber hareketlenir. Bir hemşire adayı olan Gülce, para kazanmak için yaşlı ve yalnız bir adam olan Mevlüt’ün bakıcılığını yapmaktadır. Gülce’ye yakınlaşarak onu tanımaya başlayan Ali, Mevlüt’ün hikâyesine de ortak olacaktır. Ali arayışlarını hayatındaki bu yeni hikayeler ile sürdürür. Bütün saadetler mümkün müdür?
#
# Temizlenmiş:
# ali okumak küçük şehir ayırmak Erasmus proje yurtdışı çıkmak hayal Kura bir mühendis öğrenci ayn zaman kendi tanımak çalışmak hayat dair soru sormak ali nin saki hayat bir türkü barda solist yapan gül demek hoş beraber hareketlenmek bir hemşire ada o gül par kazanmak yaş yalnız bir ada o mevlüt ün bakı yapmak gül yemek yakın o tanımak başlayan ali mevlüt ün hikâye ortak olacaktır ali arayışlarını hayat yeni hikâyelemek sürmek bütün saadet mümkün mü Dram Kemal Uçar Arif Erkin Güzelbeyoğlu Nilay Erdönmez Selman Kılıçaslan
#
# //////////////////////////////////////////////////
#
# Orijinal:
# Marissa Cortez (Jessica Alba), özel servisteki görevden ayrılarak kendisini ailesine ve çocuklarına adamaya karar veren eski bir ajandır. Fakat öğrendiği tehditkar bir haber üzerine gizli servise geri döner. Zira zamanın dengesiyle oynayarak dünyayı yok etmenin bir yolunu bulan kötü adam (Danger D'Amo) iş başındadır. Marissa gizli görevini kocasından saklamaya çalışsa da çocuklarının (Rowan Blanchard ve Mason Cook) bu macera dolu işe bulaşmasına engel olamaz.... Tarantino ile birlikte sinemanın dahi çocukları olarak anılan Robert Rodriguez imzalı, ilk kez 2001'de seyrettiğimiz "Spy Kids" serisinin bu dördüncü filminde çılgın çocukların dünyayı kurtarmaya çalışırken, sinema salonları da yeni bir deneyime tanıklık edecek. Zira yönetmen Rodriguez bu sefer sadece göze ve kulağa değil, burunlara da hitap etmenin peşinde. Aroma-Scope tekniği ile sinemaya dördüncü hissi, kokuyu da katan film bu yönüyle de merak uyandırıyor... Oyuncu kadrosunda ise Jessica Alba'nın öne çıktığı yapımda güzel oyuncunun yanı sıra kadın seyircilerin halen gözdesi olan Antonio Banderas, Alexa Vega, Danny Trejo, Jeremy Piven ve birçok çocuk yer alıyor...
#
# Temizlenmiş:
# Marissa Cortez Jessica Alba özel servis görev ayırmak kendi aile Çocuk adamak karmak vere eskimek bir ajan fakat öğrenmek tehditkâr bir haber üzeri gizli servis geri döner zira zaman denge oynayarak dünya yok etmen bir yol bulamak kötü ada Danger D Amo iş baş Marissa gizli görev koca saklamak çalışmak Çocuk Rowan Blanchard mason Cook macera do iş bulaşmak engel olamaz Tarantino Birlik sinema dâhi Çocuk olarak anı Robert Rodriguez imza ilk 2001 seyretmek Spy Kids Seri dördün film çılgın Çocuk dünya kurtarmak Çalışır sinema salon yeni bir deneyim tanık edecek zira yönetmek Rodriguez sefer sadece göze kulak değil burun hitap etmen peşin aroma Scope teknik sinema dördün hissî koku katan film yön merak uyanmak oyun kadro Jessica Alba nın önemek çıkmak yapı güzel oyun yan sıra kadın seyirci Hale gözde o Antonio Banderas Alexa Vega Danny Trejo Jeremy Piven birçok Çocuk yer alıyor Aksiyon Macera Komedi Jessica Alba Alexa PenaVega Jeremy Piven Robert Rodriguez
#
# //////////////////////////////////////////////////

# %%
df.to_csv("filmler_clean.csv", index=False)

# %%
df_diskten = pd.read_csv("filmler_clean.csv")

# %%
df_diskten.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                                                clean
# 0  ['arabesk', 'unutulmayan', 'kadın', 'ses', 'o'...
# 1  ['Çocuk', 'film', 'kirpi', 'Sonic', 'film', 'd...
# 2  ['karmak', 'büyü', 'Gellert', 'Grindelwald', '...
# 3  ['Aykut', 'enişte', '2', 'sevmek', 'kadın', 'e...
# 4  ['Morbius', 'hastalık', 'deva', 'bulmak', 'Çal...

# %%
kelime2index = {}
index2kelime = {}

# %%
kelime2index["<UNK>"] = 0
index2kelime[0] = "<UNK>"

# %%
clean_col = df["clean"]
clean_col
# Out:
# 0       [arabesk, unutulmayan, kadın, ses, o, Bergen, ...
# 1       [Çocuk, film, kirpi, Sonic, film, deva, halka,...
# 2       [karmak, büyü, Gellert, Grindelwald, büyü, dün...
# 3       [Aykut, enişte, 2, sevmek, kadın, evlilik, ari...
# 4       [Morbius, hastalık, deva, bulmak, Çalışır, bam...
#                               ...
# 5256    [Sonny, Koufax, hayat, ray, oturmak, Orta, yaş...
# 5257    [kuzey, Kıbrıs, Ta, sinema, sektör, olmak, rağ...
# 5258    [Çocuk, film, Free, Birds, özgürlük, menü, hin...
# 5259    [Neruda, 1940, larda, komünist, parti, yemek, ...
# 5260    [Ray, Gibson, hiçbir, suç, işlemek, olmak, rağ...
# Name: clean, Length: 5261, dtype: object

# %%
len(clean_col.values), len(df)
# Out:
# (5261, 5261)

# %%
i = 1
for doc in clean_col.values:
    for token in doc:
        if token in kelime2index:
            continue
        
        kelime2index[token] = i
        index2kelime[i] = token
        i += 1

# %%
kelime2index
# Out:
# {'<UNK>': 0,
#  'arabesk': 1,
#  'unutulmayan': 2,
#  'kadın': 3,
#  'ses': 4,
#  'o': 5,
#  'Bergen': 6,
#  'in': 7,
#  'hayat': 8,
#  'anlamak': 9,
#  'film': 10,
#  'olarak': 11,
#  'bilinen': 12,
#  'belgin': 13,
#  'Ankara': 14,
#  'dan': 15,
#  'ada': 16,
#  'ora': 17,
#  'yaşamak': 18,
#  'aşkın': 19,
#  'ardından': 20,
#  'ebediyet': 21,
#  'uzanmak': 22,
#  'öykü': 23,
#  '1959': 24,
#  'yıl': 25,
#  'Mers': 26,
#  'yedi': 27,
#  'çocuk': 28,
#  'bir': 29,
#  'aile': 30,
#  'küçük': 31,
#  'dünya': 32,
#  'gelir': 33,
#  'Anne': 34,
#  'baba': 35,
#  'boşanma': 36,
#  'Kökten': 37,
#  'biçim': 38,
#  'değişmek': 39,
#  'Yaşar': 40,
#  'başka': 41,
#  'kimse': 42,
#  'yok': 43,
#  'bap': 44,
#  'yoksun': 45,
#  'içinde': 46,
#  'dermek': 47,
#  'boş': 48,
#  'açmak': 49,
#  'ötmek': 50,
#  'yan': 51,
#  'konservatuar': 52,
#  'girmek': 53,
#  'başarı': 54,
#  'katmer': 55,
#  'gelecek': 56,
#  'umut': 57,
#  'ilk': 58,
#  'aşk': 59,
#  'Abdullah': 60,
#  'tan': 61,
#  'ayrılmak': 62,
#  'yaramak': 63,
#  'alır': 64,
#  'ama': 65,
#  'onmak': 66,
#  'Büyük': 67,
#  'güç': 68,
#  'yetenek': 69,
#  'nın': 70,
#  'prestij': 71,
#  'mekân': 72,
#  'Feyman': 73,
#  'Kulüp': 74,
#  'Te': 75,
#  'keşfetmek': 76,
#  'Birlik': 77,
#  'parlamak': 78,
#  'genç': 79,
#  'yıldız': 80,
#  'e': 81,
#  'dönüşmek': 82,
#  'ancak': 83,
#  'zaman': 84,
#  'koşul': 85,
#  'yapılanmak': 86,
#  'kontrat': 87,
#  'sebebiyle': 88,
#  'süre': 89,
#  'çalışmak': 90,
#  'gidermek': 91,
#  'müzikhol': 92,
#  'sahne': 93,
#  'Müzik': 94,
#  'tarz': 95,
#  'zor': 96,
#  'kalır': 97,
#  'daha': 98,
#  'sonra': 99,
#  'ev': 100,
#  'halis': 101,
#  'serbest': 102,
#  'karşılaşmak': 103,
#  'manipülatif': 104,
#  'olay': 105,
#  'dizi': 106,
#  'bulur': 107,
#  'kendi': 108,
#  'Le': 109,
#  'yapmak': 110,
#  'evlilik': 111,
#  'düşlemek': 112,
#  'tersinmek': 113,
#  'i': 114,
#  'koparır': 115,
#  'şiddet': 116,
#  'do': 117,
#  'gün': 118,
#  'tümüyle': 119,
#  'yalnız': 120,
#  'kariyer': 121,
#  'güzel': 122,
#  'yer': 123,
#  'kezzap': 124,
#  'saldırı': 125,
#  'uğramak': 126,
#  'göz': 127,
#  'kaybeder': 128,
#  'trajedi': 129,
#  'rağmen': 130,
#  'dönmek': 131,
#  'olağanüstü': 132,
#  'şarkı': 133,
#  'Türki': 134,
#  'çap': 135,
#  'Şöhret': 136,
#  'Olur': 137,
#  'tehdit': 138,
#  'taciz': 139,
#  'seyretmek': 140,
#  'gerilim': 141,
#  'ilişki': 142,
#  'gitmek': 143,
#  'Geller': 144,
#  'deva': 145,
#  'eder': 146,
#  'korku': 147,
#  'yaşarmak': 148,
#  'sonunda': 149,
#  'kes': 150,
#  'te': 151,
#  'kurtulmak': 152,
#  'düşünmek': 153,
#  'yolcu': 154,
#  'silâh': 155,
#  'ağır': 156,
#  'yaralamak': 157,
#  'henüz': 158,
#  '30': 159,
#  'yaş': 160,
#  'ölmek': 161,
#  'kurban': 162,
#  'kraliçe': 163,
#  'insan': 164,
#  'kalp': 165,
#  'kazınmak': 166,
#  'Dram': 167,
#  'Biyografik': 168,
#  'Farah Zeynep Abdullah': 169,
#  'Erdal Beşikçioğlu': 170,
#  'Tilbe Saran': 171,
#  'Mehmet Binay': 172,
#  'Caner Alper': 173,
#  'Çocuk': 174,
#  'kirpi': 175,
#  'Sonic': 176,
#  'halka': 177,
#  'yapı': 178,
#  'atılmak': 179,
#  'macera': 180,
#  'konu': 181,
#  'ediliyor': 182,
#  'Green': 183,
#  'Hills': 184,
#  'yerleşmek': 185,
#  'tek': 186,
#  'istek': 187,
#  'Gerçek': 188,
#  'kahraman': 189,
#  'olmak': 190,
#  'gereken': 191,
#  'özellik': 192,
#  'sahip': 193,
#  'kanıtlamak': 194,
#  'sınav': 195,
#  'Dr': 196,
#  'Robotnik': 197,
#  'ortak': 198,
#  'Knuckes': 199,
#  'medeniyet': 200,
#  'edebilecek': 201,
#  'Güce': 202,
#  'zümrüt': 203,
#  'aramak': 204,
#  'geri': 205,
#  'dönme': 206,
#  'baş': 207,
#  'yanlış': 208,
#  'el': 209,
#  'geçmek': 210,
#  'engellemek': 211,
#  'yardımcı': 212,
#  'Tails': 213,
#  'çıkar': 214,
#  'Animasyon': 215,
#  'Aile': 216,
#  'Macera': 217,
#  'Jim Carrey': 218,
#  'James Marsden': 219,
#  None: 220,
#  'Jeff Fowler': 221,
#  'karmak': 222,
#  'büyü': 223,
#  'Gellert': 224,
#  'Grindelwald': 225,
#  'kontrol': 226,
#  'geçirmek': 227,
#  'hareket': 228,
#  'geçmiş': 229,
#  'bu': 230,
#  'öğrenen': 231,
#  'profesör': 232,
#  'Albus': 233,
#  'Dumbledore': 234,
#  'ön': 235,
#  'durdurmak': 236,
#  'Çalışır': 237,
#  'başaramayan': 238,
#  'ara': 239,
#  'cadı': 240,
#  'Cesur': 241,
#  'Muggle': 242,
#  'fırın': 243,
#  'oluşmak': 244,
#  'ekip': 245,
#  'yönetim': 246,
#  'Büyüzoolog': 247,
#  'Newt': 248,
#  'Scamander': 249,
#  'A': 250,
#  'emanet': 251,
#  'tehlike': 252,
#  'görev': 253,
#  'üst': 254,
#  'canavar': 255,
#  'mücadele': 256,
#  'sayı': 257,
#  'Artan': 258,
#  'un': 259,
#  'mürit': 260,
#  'savaşmak': 261,
#  'giderek': 262,
#  'risk': 263,
#  'karşı': 264,
#  'Kadar': 265,
#  'kenar': 266,
#  'beklemek': 267,
#  'Fantastik': 268,
#  'Eddie Redmayne': 269,
#  'Jude Law': 270,
#  'Mads Mikkelsen': 271,
#  'David Yates': 272,
#  'Aykut': 273,
#  'enişte': 274,
#  '2': 275,
#  'sevmek': 276,
#  'arife': 277,
#  'tür': 278,
#  'bulamak': 279,
#  'hikâye': 280,
#  'ediyor': 281,
#  'Gülşah': 282,
#  'hazır': 283,
#  'I': 284,
#  'kaçırmak': 285,
#  'karar': 286,
#  'Atabeyoğlu': 287,
#  'nin': 288,
#  'damat': 289,
#  'olacağı': 290,
#  'oldukça': 291,
#  'heyecan': 292,
#  'bek': 293,
#  'durum': 294,
#  'plan': 295,
#  'alt': 296,
#  'eskimek': 297,
#  'Talat': 298,
#  'In': 299,
#  'düğü': 300,
#  'Orta': 301,
#  'çıkmak': 302,
#  'iş': 303,
#  'karışmak': 304,
#  'iyi': 305,
#  'niyet': 306,
#  'saf': 307,
#  'neden': 308,
#  'belâ': 309,
#  'çalışan': 310,
#  'başarabilecek': 311,
#  'Mi': 312,
#  'Komedi': 313,
#  'Cem Gelinoğlu': 314,
#  'Melis Babadağ': 315,
#  'Hakan Yılmaz': 316,
#  'Onur Bilgetay': 317,
#  'Morbius': 318,
#  'hastalık': 319,
#  'bulmak': 320,
#  'bambaşka': 321,
#  'varlık': 322,
#  'bili': 323,
#  'Michael': 324,
#  'muzdarip': 325,
#  'Nâdir': 326,
#  'görü': 327,
#  'kanmak': 328,
#  'deney': 329,
#  'yöntem': 330,
#  'tedavi': 331,
#  'etmek': 332,
#  'elektroşok': 333,
#  'terapi': 334,
#  'vampir': 335,
#  'yarasalar': 336,
#  'kul': 337,
#  'korkunç': 338,
#  'sonuçlamak': 339,
#  'artık': 340,
#  'hiçbir': 341,
#  'eski': 342,
#  'birçok': 343,
#  'Kalan': 344,
#  'kalmak': 345,
#  'sürek': 346,
#  'kan': 347,
#  'ihtiyaç': 348,
#  'varmak': 349,
#  'ışık': 350,
#  'imkân': 351,
#  'sorun': 352,
#  'sıra': 353,
#  'insanüstü': 354,
#  'Aksiyon': 355,
#  'Jared Leto': 356,
#  'Matt Smith (XI)': 357,
#  'Adria Arjona': 358,
#  'Daniel Espinosa': 359,
#  'kırmız': 360,
#  'ergen': 361,
#  'getirmek': 362,
#  'altı': 363,
#  'sıkışmak': 364,
#  'üç': 365,
#  'Mei': 366,
#  'Lee': 367,
#  'odak': 368,
#  'beklenti': 369,
#  'beraber': 370,
#  'karmaşmak': 371,
#  '13': 372,
#  'kızmak': 373,
#  'baskı': 374,
#  'koruyucu': 375,
#  'Ming': 376,
#  'kız': 377,
#  'uzak': 378,
#  'istemek': 379,
#  'talih': 380,
#  'hem': 381,
#  'vücut': 382,
#  'değişik': 383,
#  'uğraşan': 384,
#  'dev': 385,
#  'panda': 386,
#  'Domee Shi': 387,
#  '20': 388,
#  'Li': 389,
#  'hâlâ': 390,
#  'lise': 391,
#  'öğrenci': 392,
#  'müzeyyen': 393,
#  'çoğu': 394,
#  'Bekir': 395,
#  'ebru': 396,
#  'Hazerhan': 397,
#  'Ferdane': 398,
#  'kadir': 399,
#  'demek': 400,
#  'arkadaş': 401,
#  'grup': 402,
#  'geçirir': 403,
#  'bütün': 404,
#  'günah': 405,
#  'paylaşmak': 406,
#  'iletmek': 407,
#  'görmek': 408,
#  'dok': 409,
#  'beri': 410,
#  'haberdar': 411,
#  'kardeş': 412,
#  'ali': 413,
#  'gelmek': 414,
#  'yirmi': 415,
#  'yılmak': 416,
#  'önce': 417,
#  'Yasak': 418,
#  'hamil': 419,
#  'kalın': 420,
#  'terketmek': 421,
#  'hepsi': 422,
#  'yeni': 423,
#  'yarıyıl': 424,
#  'Tati': 425,
#  'fırsat': 426,
#  'bilerek': 427,
#  'tanışmak': 428,
#  'Antalya': 429,
#  'arka': 430,
#  'sokak': 431,
#  'Yi': 432,
#  'kabul': 433,
#  'dahil': 434,
#  'iki': 435,
#  'âmâ': 436,
#  'birinci': 437,
#  'Bolu': 438,
#  'götürüp': 439,
#  'Yaşam': 440,
#  'Standard': 441,
#  'erişmek': 442,
#  'sağlamak': 443,
#  'diğer': 444,
#  'Hazar Ergüçlü': 445,
#  'Ozan Uygun': 446,
#  'Halil Babür': 447,
#  'Emre Erdoğdu': 448,
#  'kesişmek': 449,
#  'eren': 450,
#  'Trabzon': 451,
#  'Maçka': 452,
#  'terörist': 453,
#  'Mehmet': 454,
#  'çatışmak': 455,
#  'kaybeden': 456,
#  'bülbül': 457,
#  'korumak': 458,
#  'şehit': 459,
#  'astsubay': 460,
#  'kıdem': 461,
#  'başçavuş': 462,
#  'Ferhat': 463,
#  'Gedik': 464,
#  'İsmail Hacıoğlu': 465,
#  'Rahman Başel': 466,
#  'Alayça Öztürk': 467,
#  'Özer Feyzioğlu': 468,
#  'örümcek': 469,
#  'kimlik': 470,
#  'açık': 471,
#  'sır': 472,
#  'vermek': 473,
#  'doktor': 474,
#  'Strange': 475,
#  'yardım': 476,
#  'yaşananları': 477,
#  'ifşa': 478,
#  'edilerek': 479,
#  'halk': 480,
#  'sermek': 481,
#  'kaos': 482,
#  'Peter': 483,
#  'ayn': 484,
#  'suç': 485,
#  'lanse': 486,
#  'edi': 487,
#  'MJ': 488,
#  'Ned': 489,
#  'olumsuz': 490,
#  'etki': 491,
#  'şahit': 492,
#  'üniversite': 493,
#  'şans': 494,
#  'seyirci': 495,
#  'yakarmak': 496,
#  'E': 497,
#  'unutmak': 498,
#  'nü': 499,
#  'May': 500,
#  'Happy': 501,
#  'olacaktır': 502,
#  'hatırlamak': 503,
#  'kişi': 504,
#  'yaparken': 505,
#  'parametre': 506,
#  'Tom Holland': 507,
#  'Zendaya': 508,
#  'Benedict Cumberbatch': 509,
#  'Jon Watts': 510,
#  'The': 511,
#  'Batman': 512,
#  'suçlu': 513,
#  'salâ': 514,
#  'Riddler': 515,
#  'isim': 516,
#  'Seri': 517,
#  'katil': 518,
#  'dolaşmak': 519,
#  'salmak': 520,
#  'Bruce': 521,
#  'Wayne': 522,
#  'Gotham': 523,
#  'City': 524,
#  'sürüklemek': 525,
#  'Gizem': 526,
#  'şehir': 527,
#  'seçkin': 528,
#  'Hedef': 529,
#  'alıp': 530,
#  'sadist': 531,
#  'hain': 532,
#  'iz': 533,
#  'sürme': 534,
#  'İpuçlarınını': 535,
#  'peşin': 536,
#  'Gide': 537,
#  'yol': 538,
#  'süreç': 539,
#  'Catwoman': 540,
#  'Selina': 541,
#  'Kyle': 542,
#  'penguen': 543,
#  'Oswald': 544,
#  'Cobblepot': 545,
#  'Carmine': 546,
#  'Falcone': 547,
#  'karakter': 548,
#  'kesişir': 549,
#  'kurmak': 550,
#  'maske': 551,
#  'düşürmek': 552,
#  'Ni': 553,
#  'huzur': 554,
#  'kavuşmak': 555,
#  'girişmek': 556,
#  'Polisiye': 557,
#  'Gerilim': 558,
#  'Robert Pattinson': 559,
#  'Zoë Kravitz': 560,
#  'Paul Dano': 561,
#  'Matt Reeves': 562,
#  'taş': 563,
#  'koruyucusu': 564,
#  'Sherlock': 565,
#  'kurgu': 566,
#  'dedektif': 567,
#  'rol': 568,
#  'ünlemek': 569,
#  'Wikileaks': 570,
#  'beşinci': 571,
#  'kuvvet': 572,
#  'bilinmez': 573,
#  'doğru': 574,
#  'star': 575,
#  'Trek': 576,
#  'Imitation': 577,
#  'Game': 578,
#  'Enigma': 579,
#  'yapım': 580,
#  'çıkan': 581,
#  'Benedict': 582,
#  'Cumberbatch': 583,
#  'ün': 584,
#  'veriyor': 585,
#  'yönetmek': 586,
#  'Scott': 587,
#  'Derrickson': 588,
#  'kamera': 589,
#  'Arkas': 590,
#  'geçeceği': 591,
#  'sadık': 592,
#  'usta': 593,
#  'Wong': 594,
#  'Elizabeth Olsen': 595,
#  'Rachel McAdams': 596,
#  'Sam Raimi': 597,
#  'Dilberay': 598,
#  '2019': 599,
#  'veda': 600,
#  'dilber': 601,
#  'Ay': 602,
#  'Kahramanmaraş': 603,
#  'Ta': 604,
#  'sek': 605,
#  'çadır': 606,
#  'başlayan': 607,
#  'par': 608,
#  'satmak': 609,
#  'tutku': 610,
#  'şark': 611,
#  'söylemekti': 612,
#  'yüzde': 613,
#  'dayak': 614,
#  'yemek': 615,
#  'işkence': 616,
#  'Çek': 617,
#  'acı': 618,
#  'se': 619,
#  'almak': 620,
#  'Güç': 621,
#  'adım': 622,
#  'atmak': 623,
#  'boy': 624,
#  'zirve': 625,
#  'dip': 626,
#  'vurmak': 627,
#  'düşmek': 628,
#  'kuyu': 629,
#  'söyleyerek': 630,
#  'çıktı': 631,
#  'Büşra Pekin': 632,
#  'Zeliha Kendirci': 633,
#  'Nursel Köse': 634,
#  'Ketche': 635,
#  'Doru': 636,
#  'orman': 637,
#  'kurtarmak': 638,
#  'Karatay': 639,
#  'Alaca': 640,
#  'hayvan': 641,
#  'sirk': 642,
#  'üzeri': 643,
#  'yak': 644,
#  'yı': 645,
#  'geçer': 646,
#  'zeki': 647,
#  'saye': 648,
#  'kurtaran': 649,
#  'sürpriz': 650,
#  'kaçar': 651,
#  'Bebek': 652,
#  'şempanze': 653,
#  'Şöbi': 654,
#  'Arkın Aktaç': 655,
#  '25': 656,
#  'gelen': 657,
#  'geçen': 658,
#  'Will': 659,
#  'Salas': 660,
#  'Justin': 661,
#  'Timberlake': 662,
#  'hata': 663,
#  'sonuç': 664,
#  'cinayet': 665,
#  'hüküm': 666,
#  'giymek': 667,
#  'hapishane': 668,
#  'şan': 669,
#  'yüz': 670,
#  'sistem': 671,
#  'çökermek': 672,
#  'zira': 673,
#  'rahatlıkla': 674,
#  'satı': 675,
#  'alınmak': 676,
#  'zengin': 677,
#  'sonsuz': 678,
#  'kalarak': 679,
#  'fakir': 680,
#  'ölerek': 681,
#  'üste': 682,
#  'yaşayamadıkları': 683,
#  'eklemek': 684,
#  'Güçs': 685,
#  'üzmek': 686,
#  'olanlar': 687,
#  'sadece': 688,
#  'kalabilmek': 689,
#  'dilemek': 690,
#  'ödünç': 691,
#  'hatta': 692,
#  'bazen': 693,
#  'çalarmak': 694,
#  'yoz': 695,
#  'başrol': 696,
#  'son': 697,
#  'Döne': 698,
#  'vere': 699,
#  'sinema': 700,
#  'yönelmek': 701,
#  'Scarlett': 702,
#  'Johansson': 703,
#  'anı': 704,
#  'Amanda': 705,
#  'Seyfried': 706,
#  'oyun': 707,
#  'kadro': 708,
#  'Olivia': 709,
#  'Wild': 710,
#  'Alex': 711,
#  'Pettyfer': 712,
#  'Cillian': 713,
#  'Murphy': 714,
#  'is': 715,
#  'Gattaca': 716,
#  'S1m0ne': 717,
#  'Lord': 718,
#  'Of': 719,
#  'War': 720,
#  'yazıp': 721,
#  'Truman': 722,
#  'Show': 723,
#  'terminal': 724,
#  'senaryo': 725,
#  'Kale': 726,
#  'alan': 727,
#  'Andrew': 728,
#  'Niccol': 729,
#  'proje': 730,
#  'Bilimkurgu': 731,
#  'Amanda Seyfried': 732,
#  'Justin Timberlake': 733,
#  'Cillian Murphy': 734,
#  'Andrew Niccol': 735,
#  'edebiyat': 736,
#  'Anastasia': 737,
#  'Steel': 738,
#  'çeki': 739,
#  'Christian': 740,
#  'Grey': 741,
#  'röportaj': 742,
#  'görüşmek': 743,
#  'tavır': 744,
#  'biraz': 745,
#  'mesafe': 746,
#  'durmak': 747,
#  'yakışık': 748,
#  'Cazibe': 749,
#  'koyamaz': 750,
#  'çekim': 751,
#  'bırakır': 752,
#  'fakat': 753,
#  'şe': 754,
#  'nokta': 755,
#  'Ulaş': 756,
#  'seks': 757,
#  'söz': 758,
#  'olunca': 759,
#  'bilmek': 760,
#  'gizli': 761,
#  'şehvet': 762,
#  'sapacak': 763,
#  'mı': 764,
#  'L': 765,
#  'James': 766,
#  'liste': 767,
#  'inmek': 768,
#  'ad': 769,
#  'roman': 770,
#  'uyarlamak': 771,
#  'yönetmen': 772,
#  'sam': 773,
#  'Taylor': 774,
#  'Johnson': 775,
#  'Jamie': 776,
#  'Dornan': 777,
#  'Dakota': 778,
#  'Romantik': 779,
#  'Jamie Dornan': 780,
#  'Dakota Johnson': 781,
#  'Jennifer Ehle': 782,
#  'Sam Taylor-Johnson': 783,
#  'Recep': 784,
#  'İvedik': 785,
#  '6': 786,
#  'Konya': 787,
#  'gider': 788,
#  'Kenya': 789,
#  'davet': 790,
#  'hâl': 791,
#  'kur': 792,
#  'fasulye': 793,
#  'festival': 794,
#  'çağırılmaktadır': 795,
#  'memnuniyet': 796,
#  'karşılamak': 797,
#  'Nurullah': 798,
#  'alarak': 799,
#  'yolmak': 800,
#  'koyulur': 801,
#  'başlamak': 802,
#  'yaşayan': 803,
#  'yerine': 804,
#  'seyahat': 805,
#  'acente': 806,
#  'Arar': 807,
#  'coğrafya': 808,
#  'bulunan': 809,
#  'birden': 810,
#  'düşman': 811,
#  'kabile': 812,
#  'has': 813,
#  'bulunmak': 814,
#  'vahşî': 815,
#  'ayakta': 816,
#  'birbiri': 817,
#  'ilginç': 818,
#  'Şahan Gökbakar': 819,
#  'Nurullah Çelebi': 820,
#  'Somer Karvan': 821,
#  'Togan Gökbakar': 822,
#  'milyoner': 823,
#  'bırakmak': 824,
#  'sandık': 825,
#  'kolay': 826,
#  'olmaz': 827,
#  'çift': 828,
#  'barışmak': 829,
#  'bitmek': 830,
#  'şeytan': 831,
#  'yüzleşmek': 832,
#  'kalırken': 833,
#  'öfke': 834,
#  'kıskanç': 835,
#  'üstlenmek': 836,
#  'Ty': 837,
#  'Hoechlin': 838,
#  'kim': 839,
#  'Basinger': 840,
#  'Marcia': 841,
#  'Gay': 842,
#  'Harden': 843,
#  'Bella': 844,
#  'Heathcote': 845,
#  'alıyor': 846,
#  'Erotik': 847,
#  'Bella Heathcote': 848,
#  'James Foley': 849,
#  'Day': 850,
#  'sevi': 851,
#  'kabadayı': 852,
#  'adalet': 853,
#  'Duygu': 854,
#  'iç': 855,
#  'cesaret': 856,
#  'merhamet': 857,
#  'haylaz': 858,
#  'bıkmak': 859,
#  'tarafından': 860,
#  'köy': 861,
#  'İstanbul': 862,
#  'göndermek': 863,
#  'kahve': 864,
#  'yapan': 865,
#  'Seyfi': 866,
#  'yanında': 867,
#  'ailemine': 868,
#  'girer': 869,
#  'Yükselir': 870,
#  'Ufuk Bayraktar': 871,
#  'Gizem Karaca': 872,
#  'Ahmet Varlı': 873,
#  'Uğur Bayraktar': 874,
#  'kaymak': 875,
#  'yazmak': 876,
#  'Roma': 877,
#  'yazar': 878,
#  'Loretta': 879,
#  'Sage': 880,
#  'inziva': 881,
#  'çekilmek': 882,
#  'Dash': 883,
#  'Can': 884,
#  'adamak': 885,
#  'kapak': 886,
#  'model': 887,
#  'popüler': 888,
#  'egzotik': 889,
#  'Hak': 890,
#  'yazarak': 891,
#  'Kitab': 892,
#  'tanıtı': 893,
#  'turne': 894,
#  'eksantrik': 895,
#  'milyarder': 896,
#  'Kitap': 897,
#  'antik': 898,
#  'hazine': 899,
#  'götürebileceğini': 900,
#  'Vakit': 901,
#  'kaybetmek': 902,
#  'ant': 903,
#  'Sandra Bullock': 904,
#  'Channing Tatum': 905,
#  'Daniel Radcliffe': 906,
#  'Aaron Nee': 907,
#  'Adam Nee': 908,
#  'Uygun': 909,
#  'düşen': 910,
#  'yetkili': 911,
#  'kurtulup': 912,
#  'şeytanî': 913,
#  'Yüzük': 914,
#  'hükümet': 915,
#  'yakalamak': 916,
#  'düşer': 917,
#  'devlet': 918,
#  'Eggman': 919,
#  'kasaba': 920,
#  'şerif': 921,
#  'Tom': 922,
#  'Wachowski': 923,
#  'kaçmak': 924,
#  'başarıp': 925,
#  'alabilmesi': 926,
#  'verir': 927,
#  'kuzey': 928,
#  'intikam': 929,
#  'Viking': 930,
#  'prens': 931,
#  'kral': 932,
#  'Aurvandil': 933,
#  'imparator': 934,
#  'oğul': 935,
#  'Amleth': 936,
#  'devretmek': 937,
#  'üvey': 938,
#  'Fjölnir': 939,
#  'taht': 940,
#  'başaran': 941,
#  'amca': 942,
#  'Gudrun': 943,
#  'U': 944,
#  'Görür': 945,
#  'alacak': 946,
#  'kurtaracağına': 947,
#  'yemin': 948,
#  'Slav': 949,
#  'akın': 950,
#  'savaş': 951,
#  'kâhin': 952,
#  'tutmak': 953,
#  'Tarihi': 954,
#  'Alexander Skarsgård': 955,
#  'Nicole Kidman': 956,
#  'Claes Bang': 957,
#  'Robert Eggers': 958,
#  'Dune': 959,
#  'çöl': 960,
#  'gezegen': 961,
#  'Arrakis': 962,
#  'Paul': 963,
#  'Atreides': 964,
#  'galâksi': 965,
#  'fark': 966,
#  'rakip': 967,
#  'feodal': 968,
#  'çok': 969,
#  'değer': 970,
#  'kaynak': 971,
#  'üretmek': 972,
#  'asil': 973,
#  'derece': 974,
#  'talep': 975,
#  'baharat': 976,
#  'veri': 977,
#  'Yüksek': 978,
#  'bilinç': 979,
#  'uz': 980,
#  'sunmak': 981,
#  'ciddi': 982,
#  'yanmak': 983,
#  'ayrı': 984,
#  'yıldızlararası': 985,
#  'gezinmek': 986,
#  'tır': 987,
#  'elde': 988,
#  'Harkonen': 989,
#  'tuzak': 990,
#  'kurulur': 991,
#  'darmadağın': 992,
#  'firarî': 993,
#  'Hale': 994,
#  'kazanmak': 995,
#  'isyan': 996,
#  'evren': 997,
#  'seyir': 998,
#  'ihtimalî': 999,
#  ...}

# %%
index2kelime
# Out:
# {0: '<UNK>',
#  1: 'arabesk',
#  2: 'unutulmayan',
#  3: 'kadın',
#  4: 'ses',
#  5: 'o',
#  6: 'Bergen',
#  7: 'in',
#  8: 'hayat',
#  9: 'anlamak',
#  10: 'film',
#  11: 'olarak',
#  12: 'bilinen',
#  13: 'belgin',
#  14: 'Ankara',
#  15: 'dan',
#  16: 'ada',
#  17: 'ora',
#  18: 'yaşamak',
#  19: 'aşkın',
#  20: 'ardından',
#  21: 'ebediyet',
#  22: 'uzanmak',
#  23: 'öykü',
#  24: '1959',
#  25: 'yıl',
#  26: 'Mers',
#  27: 'yedi',
#  28: 'çocuk',
#  29: 'bir',
#  30: 'aile',
#  31: 'küçük',
#  32: 'dünya',
#  33: 'gelir',
#  34: 'Anne',
#  35: 'baba',
#  36: 'boşanma',
#  37: 'Kökten',
#  38: 'biçim',
#  39: 'değişmek',
#  40: 'Yaşar',
#  41: 'başka',
#  42: 'kimse',
#  43: 'yok',
#  44: 'bap',
#  45: 'yoksun',
#  46: 'içinde',
#  47: 'dermek',
#  48: 'boş',
#  49: 'açmak',
#  50: 'ötmek',
#  51: 'yan',
#  52: 'konservatuar',
#  53: 'girmek',
#  54: 'başarı',
#  55: 'katmer',
#  56: 'gelecek',
#  57: 'umut',
#  58: 'ilk',
#  59: 'aşk',
#  60: 'Abdullah',
#  61: 'tan',
#  62: 'ayrılmak',
#  63: 'yaramak',
#  64: 'alır',
#  65: 'ama',
#  66: 'onmak',
#  67: 'Büyük',
#  68: 'güç',
#  69: 'yetenek',
#  70: 'nın',
#  71: 'prestij',
#  72: 'mekân',
#  73: 'Feyman',
#  74: 'Kulüp',
#  75: 'Te',
#  76: 'keşfetmek',
#  77: 'Birlik',
#  78: 'parlamak',
#  79: 'genç',
#  80: 'yıldız',
#  81: 'e',
#  82: 'dönüşmek',
#  83: 'ancak',
#  84: 'zaman',
#  85: 'koşul',
#  86: 'yapılanmak',
#  87: 'kontrat',
#  88: 'sebebiyle',
#  89: 'süre',
#  90: 'çalışmak',
#  91: 'gidermek',
#  92: 'müzikhol',
#  93: 'sahne',
#  94: 'Müzik',
#  95: 'tarz',
#  96: 'zor',
#  97: 'kalır',
#  98: 'daha',
#  99: 'sonra',
#  100: 'ev',
#  101: 'halis',
#  102: 'serbest',
#  103: 'karşılaşmak',
#  104: 'manipülatif',
#  105: 'olay',
#  106: 'dizi',
#  107: 'bulur',
#  108: 'kendi',
#  109: 'Le',
#  110: 'yapmak',
#  111: 'evlilik',
#  112: 'düşlemek',
#  113: 'tersinmek',
#  114: 'i',
#  115: 'koparır',
#  116: 'şiddet',
#  117: 'do',
#  118: 'gün',
#  119: 'tümüyle',
#  120: 'yalnız',
#  121: 'kariyer',
#  122: 'güzel',
#  123: 'yer',
#  124: 'kezzap',
#  125: 'saldırı',
#  126: 'uğramak',
#  127: 'göz',
#  128: 'kaybeder',
#  129: 'trajedi',
#  130: 'rağmen',
#  131: 'dönmek',
#  132: 'olağanüstü',
#  133: 'şarkı',
#  134: 'Türki',
#  135: 'çap',
#  136: 'Şöhret',
#  137: 'Olur',
#  138: 'tehdit',
#  139: 'taciz',
#  140: 'seyretmek',
#  141: 'gerilim',
#  142: 'ilişki',
#  143: 'gitmek',
#  144: 'Geller',
#  145: 'deva',
#  146: 'eder',
#  147: 'korku',
#  148: 'yaşarmak',
#  149: 'sonunda',
#  150: 'kes',
#  151: 'te',
#  152: 'kurtulmak',
#  153: 'düşünmek',
#  154: 'yolcu',
#  155: 'silâh',
#  156: 'ağır',
#  157: 'yaralamak',
#  158: 'henüz',
#  159: '30',
#  160: 'yaş',
#  161: 'ölmek',
#  162: 'kurban',
#  163: 'kraliçe',
#  164: 'insan',
#  165: 'kalp',
#  166: 'kazınmak',
#  167: 'Dram',
#  168: 'Biyografik',
#  169: 'Farah Zeynep Abdullah',
#  170: 'Erdal Beşikçioğlu',
#  171: 'Tilbe Saran',
#  172: 'Mehmet Binay',
#  173: 'Caner Alper',
#  174: 'Çocuk',
#  175: 'kirpi',
#  176: 'Sonic',
#  177: 'halka',
#  178: 'yapı',
#  179: 'atılmak',
#  180: 'macera',
#  181: 'konu',
#  182: 'ediliyor',
#  183: 'Green',
#  184: 'Hills',
#  185: 'yerleşmek',
#  186: 'tek',
#  187: 'istek',
#  188: 'Gerçek',
#  189: 'kahraman',
#  190: 'olmak',
#  191: 'gereken',
#  192: 'özellik',
#  193: 'sahip',
#  194: 'kanıtlamak',
#  195: 'sınav',
#  196: 'Dr',
#  197: 'Robotnik',
#  198: 'ortak',
#  199: 'Knuckes',
#  200: 'medeniyet',
#  201: 'edebilecek',
#  202: 'Güce',
#  203: 'zümrüt',
#  204: 'aramak',
#  205: 'geri',
#  206: 'dönme',
#  207: 'baş',
#  208: 'yanlış',
#  209: 'el',
#  210: 'geçmek',
#  211: 'engellemek',
#  212: 'yardımcı',
#  213: 'Tails',
#  214: 'çıkar',
#  215: 'Animasyon',
#  216: 'Aile',
#  217: 'Macera',
#  218: 'Jim Carrey',
#  219: 'James Marsden',
#  220: None,
#  221: 'Jeff Fowler',
#  222: 'karmak',
#  223: 'büyü',
#  224: 'Gellert',
#  225: 'Grindelwald',
#  226: 'kontrol',
#  227: 'geçirmek',
#  228: 'hareket',
#  229: 'geçmiş',
#  230: 'bu',
#  231: 'öğrenen',
#  232: 'profesör',
#  233: 'Albus',
#  234: 'Dumbledore',
#  235: 'ön',
#  236: 'durdurmak',
#  237: 'Çalışır',
#  238: 'başaramayan',
#  239: 'ara',
#  240: 'cadı',
#  241: 'Cesur',
#  242: 'Muggle',
#  243: 'fırın',
#  244: 'oluşmak',
#  245: 'ekip',
#  246: 'yönetim',
#  247: 'Büyüzoolog',
#  248: 'Newt',
#  249: 'Scamander',
#  250: 'A',
#  251: 'emanet',
#  252: 'tehlike',
#  253: 'görev',
#  254: 'üst',
#  255: 'canavar',
#  256: 'mücadele',
#  257: 'sayı',
#  258: 'Artan',
#  259: 'un',
#  260: 'mürit',
#  261: 'savaşmak',
#  262: 'giderek',
#  263: 'risk',
#  264: 'karşı',
#  265: 'Kadar',
#  266: 'kenar',
#  267: 'beklemek',
#  268: 'Fantastik',
#  269: 'Eddie Redmayne',
#  270: 'Jude Law',
#  271: 'Mads Mikkelsen',
#  272: 'David Yates',
#  273: 'Aykut',
#  274: 'enişte',
#  275: '2',
#  276: 'sevmek',
#  277: 'arife',
#  278: 'tür',
#  279: 'bulamak',
#  280: 'hikâye',
#  281: 'ediyor',
#  282: 'Gülşah',
#  283: 'hazır',
#  284: 'I',
#  285: 'kaçırmak',
#  286: 'karar',
#  287: 'Atabeyoğlu',
#  288: 'nin',
#  289: 'damat',
#  290: 'olacağı',
#  291: 'oldukça',
#  292: 'heyecan',
#  293: 'bek',
#  294: 'durum',
#  295: 'plan',
#  296: 'alt',
#  297: 'eskimek',
#  298: 'Talat',
#  299: 'In',
#  300: 'düğü',
#  301: 'Orta',
#  302: 'çıkmak',
#  303: 'iş',
#  304: 'karışmak',
#  305: 'iyi',
#  306: 'niyet',
#  307: 'saf',
#  308: 'neden',
#  309: 'belâ',
#  310: 'çalışan',
#  311: 'başarabilecek',
#  312: 'Mi',
#  313: 'Komedi',
#  314: 'Cem Gelinoğlu',
#  315: 'Melis Babadağ',
#  316: 'Hakan Yılmaz',
#  317: 'Onur Bilgetay',
#  318: 'Morbius',
#  319: 'hastalık',
#  320: 'bulmak',
#  321: 'bambaşka',
#  322: 'varlık',
#  323: 'bili',
#  324: 'Michael',
#  325: 'muzdarip',
#  326: 'Nâdir',
#  327: 'görü',
#  328: 'kanmak',
#  329: 'deney',
#  330: 'yöntem',
#  331: 'tedavi',
#  332: 'etmek',
#  333: 'elektroşok',
#  334: 'terapi',
#  335: 'vampir',
#  336: 'yarasalar',
#  337: 'kul',
#  338: 'korkunç',
#  339: 'sonuçlamak',
#  340: 'artık',
#  341: 'hiçbir',
#  342: 'eski',
#  343: 'birçok',
#  344: 'Kalan',
#  345: 'kalmak',
#  346: 'sürek',
#  347: 'kan',
#  348: 'ihtiyaç',
#  349: 'varmak',
#  350: 'ışık',
#  351: 'imkân',
#  352: 'sorun',
#  353: 'sıra',
#  354: 'insanüstü',
#  355: 'Aksiyon',
#  356: 'Jared Leto',
#  357: 'Matt Smith (XI)',
#  358: 'Adria Arjona',
#  359: 'Daniel Espinosa',
#  360: 'kırmız',
#  361: 'ergen',
#  362: 'getirmek',
#  363: 'altı',
#  364: 'sıkışmak',
#  365: 'üç',
#  366: 'Mei',
#  367: 'Lee',
#  368: 'odak',
#  369: 'beklenti',
#  370: 'beraber',
#  371: 'karmaşmak',
#  372: '13',
#  373: 'kızmak',
#  374: 'baskı',
#  375: 'koruyucu',
#  376: 'Ming',
#  377: 'kız',
#  378: 'uzak',
#  379: 'istemek',
#  380: 'talih',
#  381: 'hem',
#  382: 'vücut',
#  383: 'değişik',
#  384: 'uğraşan',
#  385: 'dev',
#  386: 'panda',
#  387: 'Domee Shi',
#  388: '20',
#  389: 'Li',
#  390: 'hâlâ',
#  391: 'lise',
#  392: 'öğrenci',
#  393: 'müzeyyen',
#  394: 'çoğu',
#  395: 'Bekir',
#  396: 'ebru',
#  397: 'Hazerhan',
#  398: 'Ferdane',
#  399: 'kadir',
#  400: 'demek',
#  401: 'arkadaş',
#  402: 'grup',
#  403: 'geçirir',
#  404: 'bütün',
#  405: 'günah',
#  406: 'paylaşmak',
#  407: 'iletmek',
#  408: 'görmek',
#  409: 'dok',
#  410: 'beri',
#  411: 'haberdar',
#  412: 'kardeş',
#  413: 'ali',
#  414: 'gelmek',
#  415: 'yirmi',
#  416: 'yılmak',
#  417: 'önce',
#  418: 'Yasak',
#  419: 'hamil',
#  420: 'kalın',
#  421: 'terketmek',
#  422: 'hepsi',
#  423: 'yeni',
#  424: 'yarıyıl',
#  425: 'Tati',
#  426: 'fırsat',
#  427: 'bilerek',
#  428: 'tanışmak',
#  429: 'Antalya',
#  430: 'arka',
#  431: 'sokak',
#  432: 'Yi',
#  433: 'kabul',
#  434: 'dahil',
#  435: 'iki',
#  436: 'âmâ',
#  437: 'birinci',
#  438: 'Bolu',
#  439: 'götürüp',
#  440: 'Yaşam',
#  441: 'Standard',
#  442: 'erişmek',
#  443: 'sağlamak',
#  444: 'diğer',
#  445: 'Hazar Ergüçlü',
#  446: 'Ozan Uygun',
#  447: 'Halil Babür',
#  448: 'Emre Erdoğdu',
#  449: 'kesişmek',
#  450: 'eren',
#  451: 'Trabzon',
#  452: 'Maçka',
#  453: 'terörist',
#  454: 'Mehmet',
#  455: 'çatışmak',
#  456: 'kaybeden',
#  457: 'bülbül',
#  458: 'korumak',
#  459: 'şehit',
#  460: 'astsubay',
#  461: 'kıdem',
#  462: 'başçavuş',
#  463: 'Ferhat',
#  464: 'Gedik',
#  465: 'İsmail Hacıoğlu',
#  466: 'Rahman Başel',
#  467: 'Alayça Öztürk',
#  468: 'Özer Feyzioğlu',
#  469: 'örümcek',
#  470: 'kimlik',
#  471: 'açık',
#  472: 'sır',
#  473: 'vermek',
#  474: 'doktor',
#  475: 'Strange',
#  476: 'yardım',
#  477: 'yaşananları',
#  478: 'ifşa',
#  479: 'edilerek',
#  480: 'halk',
#  481: 'sermek',
#  482: 'kaos',
#  483: 'Peter',
#  484: 'ayn',
#  485: 'suç',
#  486: 'lanse',
#  487: 'edi',
#  488: 'MJ',
#  489: 'Ned',
#  490: 'olumsuz',
#  491: 'etki',
#  492: 'şahit',
#  493: 'üniversite',
#  494: 'şans',
#  495: 'seyirci',
#  496: 'yakarmak',
#  497: 'E',
#  498: 'unutmak',
#  499: 'nü',
#  500: 'May',
#  501: 'Happy',
#  502: 'olacaktır',
#  503: 'hatırlamak',
#  504: 'kişi',
#  505: 'yaparken',
#  506: 'parametre',
#  507: 'Tom Holland',
#  508: 'Zendaya',
#  509: 'Benedict Cumberbatch',
#  510: 'Jon Watts',
#  511: 'The',
#  512: 'Batman',
#  513: 'suçlu',
#  514: 'salâ',
#  515: 'Riddler',
#  516: 'isim',
#  517: 'Seri',
#  518: 'katil',
#  519: 'dolaşmak',
#  520: 'salmak',
#  521: 'Bruce',
#  522: 'Wayne',
#  523: 'Gotham',
#  524: 'City',
#  525: 'sürüklemek',
#  526: 'Gizem',
#  527: 'şehir',
#  528: 'seçkin',
#  529: 'Hedef',
#  530: 'alıp',
#  531: 'sadist',
#  532: 'hain',
#  533: 'iz',
#  534: 'sürme',
#  535: 'İpuçlarınını',
#  536: 'peşin',
#  537: 'Gide',
#  538: 'yol',
#  539: 'süreç',
#  540: 'Catwoman',
#  541: 'Selina',
#  542: 'Kyle',
#  543: 'penguen',
#  544: 'Oswald',
#  545: 'Cobblepot',
#  546: 'Carmine',
#  547: 'Falcone',
#  548: 'karakter',
#  549: 'kesişir',
#  550: 'kurmak',
#  551: 'maske',
#  552: 'düşürmek',
#  553: 'Ni',
#  554: 'huzur',
#  555: 'kavuşmak',
#  556: 'girişmek',
#  557: 'Polisiye',
#  558: 'Gerilim',
#  559: 'Robert Pattinson',
#  560: 'Zoë Kravitz',
#  561: 'Paul Dano',
#  562: 'Matt Reeves',
#  563: 'taş',
#  564: 'koruyucusu',
#  565: 'Sherlock',
#  566: 'kurgu',
#  567: 'dedektif',
#  568: 'rol',
#  569: 'ünlemek',
#  570: 'Wikileaks',
#  571: 'beşinci',
#  572: 'kuvvet',
#  573: 'bilinmez',
#  574: 'doğru',
#  575: 'star',
#  576: 'Trek',
#  577: 'Imitation',
#  578: 'Game',
#  579: 'Enigma',
#  580: 'yapım',
#  581: 'çıkan',
#  582: 'Benedict',
#  583: 'Cumberbatch',
#  584: 'ün',
#  585: 'veriyor',
#  586: 'yönetmek',
#  587: 'Scott',
#  588: 'Derrickson',
#  589: 'kamera',
#  590: 'Arkas',
#  591: 'geçeceği',
#  592: 'sadık',
#  593: 'usta',
#  594: 'Wong',
#  595: 'Elizabeth Olsen',
#  596: 'Rachel McAdams',
#  597: 'Sam Raimi',
#  598: 'Dilberay',
#  599: '2019',
#  600: 'veda',
#  601: 'dilber',
#  602: 'Ay',
#  603: 'Kahramanmaraş',
#  604: 'Ta',
#  605: 'sek',
#  606: 'çadır',
#  607: 'başlayan',
#  608: 'par',
#  609: 'satmak',
#  610: 'tutku',
#  611: 'şark',
#  612: 'söylemekti',
#  613: 'yüzde',
#  614: 'dayak',
#  615: 'yemek',
#  616: 'işkence',
#  617: 'Çek',
#  618: 'acı',
#  619: 'se',
#  620: 'almak',
#  621: 'Güç',
#  622: 'adım',
#  623: 'atmak',
#  624: 'boy',
#  625: 'zirve',
#  626: 'dip',
#  627: 'vurmak',
#  628: 'düşmek',
#  629: 'kuyu',
#  630: 'söyleyerek',
#  631: 'çıktı',
#  632: 'Büşra Pekin',
#  633: 'Zeliha Kendirci',
#  634: 'Nursel Köse',
#  635: 'Ketche',
#  636: 'Doru',
#  637: 'orman',
#  638: 'kurtarmak',
#  639: 'Karatay',
#  640: 'Alaca',
#  641: 'hayvan',
#  642: 'sirk',
#  643: 'üzeri',
#  644: 'yak',
#  645: 'yı',
#  646: 'geçer',
#  647: 'zeki',
#  648: 'saye',
#  649: 'kurtaran',
#  650: 'sürpriz',
#  651: 'kaçar',
#  652: 'Bebek',
#  653: 'şempanze',
#  654: 'Şöbi',
#  655: 'Arkın Aktaç',
#  656: '25',
#  657: 'gelen',
#  658: 'geçen',
#  659: 'Will',
#  660: 'Salas',
#  661: 'Justin',
#  662: 'Timberlake',
#  663: 'hata',
#  664: 'sonuç',
#  665: 'cinayet',
#  666: 'hüküm',
#  667: 'giymek',
#  668: 'hapishane',
#  669: 'şan',
#  670: 'yüz',
#  671: 'sistem',
#  672: 'çökermek',
#  673: 'zira',
#  674: 'rahatlıkla',
#  675: 'satı',
#  676: 'alınmak',
#  677: 'zengin',
#  678: 'sonsuz',
#  679: 'kalarak',
#  680: 'fakir',
#  681: 'ölerek',
#  682: 'üste',
#  683: 'yaşayamadıkları',
#  684: 'eklemek',
#  685: 'Güçs',
#  686: 'üzmek',
#  687: 'olanlar',
#  688: 'sadece',
#  689: 'kalabilmek',
#  690: 'dilemek',
#  691: 'ödünç',
#  692: 'hatta',
#  693: 'bazen',
#  694: 'çalarmak',
#  695: 'yoz',
#  696: 'başrol',
#  697: 'son',
#  698: 'Döne',
#  699: 'vere',
#  700: 'sinema',
#  701: 'yönelmek',
#  702: 'Scarlett',
#  703: 'Johansson',
#  704: 'anı',
#  705: 'Amanda',
#  706: 'Seyfried',
#  707: 'oyun',
#  708: 'kadro',
#  709: 'Olivia',
#  710: 'Wild',
#  711: 'Alex',
#  712: 'Pettyfer',
#  713: 'Cillian',
#  714: 'Murphy',
#  715: 'is',
#  716: 'Gattaca',
#  717: 'S1m0ne',
#  718: 'Lord',
#  719: 'Of',
#  720: 'War',
#  721: 'yazıp',
#  722: 'Truman',
#  723: 'Show',
#  724: 'terminal',
#  725: 'senaryo',
#  726: 'Kale',
#  727: 'alan',
#  728: 'Andrew',
#  729: 'Niccol',
#  730: 'proje',
#  731: 'Bilimkurgu',
#  732: 'Amanda Seyfried',
#  733: 'Justin Timberlake',
#  734: 'Cillian Murphy',
#  735: 'Andrew Niccol',
#  736: 'edebiyat',
#  737: 'Anastasia',
#  738: 'Steel',
#  739: 'çeki',
#  740: 'Christian',
#  741: 'Grey',
#  742: 'röportaj',
#  743: 'görüşmek',
#  744: 'tavır',
#  745: 'biraz',
#  746: 'mesafe',
#  747: 'durmak',
#  748: 'yakışık',
#  749: 'Cazibe',
#  750: 'koyamaz',
#  751: 'çekim',
#  752: 'bırakır',
#  753: 'fakat',
#  754: 'şe',
#  755: 'nokta',
#  756: 'Ulaş',
#  757: 'seks',
#  758: 'söz',
#  759: 'olunca',
#  760: 'bilmek',
#  761: 'gizli',
#  762: 'şehvet',
#  763: 'sapacak',
#  764: 'mı',
#  765: 'L',
#  766: 'James',
#  767: 'liste',
#  768: 'inmek',
#  769: 'ad',
#  770: 'roman',
#  771: 'uyarlamak',
#  772: 'yönetmen',
#  773: 'sam',
#  774: 'Taylor',
#  775: 'Johnson',
#  776: 'Jamie',
#  777: 'Dornan',
#  778: 'Dakota',
#  779: 'Romantik',
#  780: 'Jamie Dornan',
#  781: 'Dakota Johnson',
#  782: 'Jennifer Ehle',
#  783: 'Sam Taylor-Johnson',
#  784: 'Recep',
#  785: 'İvedik',
#  786: '6',
#  787: 'Konya',
#  788: 'gider',
#  789: 'Kenya',
#  790: 'davet',
#  791: 'hâl',
#  792: 'kur',
#  793: 'fasulye',
#  794: 'festival',
#  795: 'çağırılmaktadır',
#  796: 'memnuniyet',
#  797: 'karşılamak',
#  798: 'Nurullah',
#  799: 'alarak',
#  800: 'yolmak',
#  801: 'koyulur',
#  802: 'başlamak',
#  803: 'yaşayan',
#  804: 'yerine',
#  805: 'seyahat',
#  806: 'acente',
#  807: 'Arar',
#  808: 'coğrafya',
#  809: 'bulunan',
#  810: 'birden',
#  811: 'düşman',
#  812: 'kabile',
#  813: 'has',
#  814: 'bulunmak',
#  815: 'vahşî',
#  816: 'ayakta',
#  817: 'birbiri',
#  818: 'ilginç',
#  819: 'Şahan Gökbakar',
#  820: 'Nurullah Çelebi',
#  821: 'Somer Karvan',
#  822: 'Togan Gökbakar',
#  823: 'milyoner',
#  824: 'bırakmak',
#  825: 'sandık',
#  826: 'kolay',
#  827: 'olmaz',
#  828: 'çift',
#  829: 'barışmak',
#  830: 'bitmek',
#  831: 'şeytan',
#  832: 'yüzleşmek',
#  833: 'kalırken',
#  834: 'öfke',
#  835: 'kıskanç',
#  836: 'üstlenmek',
#  837: 'Ty',
#  838: 'Hoechlin',
#  839: 'kim',
#  840: 'Basinger',
#  841: 'Marcia',
#  842: 'Gay',
#  843: 'Harden',
#  844: 'Bella',
#  845: 'Heathcote',
#  846: 'alıyor',
#  847: 'Erotik',
#  848: 'Bella Heathcote',
#  849: 'James Foley',
#  850: 'Day',
#  851: 'sevi',
#  852: 'kabadayı',
#  853: 'adalet',
#  854: 'Duygu',
#  855: 'iç',
#  856: 'cesaret',
#  857: 'merhamet',
#  858: 'haylaz',
#  859: 'bıkmak',
#  860: 'tarafından',
#  861: 'köy',
#  862: 'İstanbul',
#  863: 'göndermek',
#  864: 'kahve',
#  865: 'yapan',
#  866: 'Seyfi',
#  867: 'yanında',
#  868: 'ailemine',
#  869: 'girer',
#  870: 'Yükselir',
#  871: 'Ufuk Bayraktar',
#  872: 'Gizem Karaca',
#  873: 'Ahmet Varlı',
#  874: 'Uğur Bayraktar',
#  875: 'kaymak',
#  876: 'yazmak',
#  877: 'Roma',
#  878: 'yazar',
#  879: 'Loretta',
#  880: 'Sage',
#  881: 'inziva',
#  882: 'çekilmek',
#  883: 'Dash',
#  884: 'Can',
#  885: 'adamak',
#  886: 'kapak',
#  887: 'model',
#  888: 'popüler',
#  889: 'egzotik',
#  890: 'Hak',
#  891: 'yazarak',
#  892: 'Kitab',
#  893: 'tanıtı',
#  894: 'turne',
#  895: 'eksantrik',
#  896: 'milyarder',
#  897: 'Kitap',
#  898: 'antik',
#  899: 'hazine',
#  900: 'götürebileceğini',
#  901: 'Vakit',
#  902: 'kaybetmek',
#  903: 'ant',
#  904: 'Sandra Bullock',
#  905: 'Channing Tatum',
#  906: 'Daniel Radcliffe',
#  907: 'Aaron Nee',
#  908: 'Adam Nee',
#  909: 'Uygun',
#  910: 'düşen',
#  911: 'yetkili',
#  912: 'kurtulup',
#  913: 'şeytanî',
#  914: 'Yüzük',
#  915: 'hükümet',
#  916: 'yakalamak',
#  917: 'düşer',
#  918: 'devlet',
#  919: 'Eggman',
#  920: 'kasaba',
#  921: 'şerif',
#  922: 'Tom',
#  923: 'Wachowski',
#  924: 'kaçmak',
#  925: 'başarıp',
#  926: 'alabilmesi',
#  927: 'verir',
#  928: 'kuzey',
#  929: 'intikam',
#  930: 'Viking',
#  931: 'prens',
#  932: 'kral',
#  933: 'Aurvandil',
#  934: 'imparator',
#  935: 'oğul',
#  936: 'Amleth',
#  937: 'devretmek',
#  938: 'üvey',
#  939: 'Fjölnir',
#  940: 'taht',
#  941: 'başaran',
#  942: 'amca',
#  943: 'Gudrun',
#  944: 'U',
#  945: 'Görür',
#  946: 'alacak',
#  947: 'kurtaracağına',
#  948: 'yemin',
#  949: 'Slav',
#  950: 'akın',
#  951: 'savaş',
#  952: 'kâhin',
#  953: 'tutmak',
#  954: 'Tarihi',
#  955: 'Alexander Skarsgård',
#  956: 'Nicole Kidman',
#  957: 'Claes Bang',
#  958: 'Robert Eggers',
#  959: 'Dune',
#  960: 'çöl',
#  961: 'gezegen',
#  962: 'Arrakis',
#  963: 'Paul',
#  964: 'Atreides',
#  965: 'galâksi',
#  966: 'fark',
#  967: 'rakip',
#  968: 'feodal',
#  969: 'çok',
#  970: 'değer',
#  971: 'kaynak',
#  972: 'üretmek',
#  973: 'asil',
#  974: 'derece',
#  975: 'talep',
#  976: 'baharat',
#  977: 'veri',
#  978: 'Yüksek',
#  979: 'bilinç',
#  980: 'uz',
#  981: 'sunmak',
#  982: 'ciddi',
#  983: 'yanmak',
#  984: 'ayrı',
#  985: 'yıldızlararası',
#  986: 'gezinmek',
#  987: 'tır',
#  988: 'elde',
#  989: 'Harkonen',
#  990: 'tuzak',
#  991: 'kurulur',
#  992: 'darmadağın',
#  993: 'firarî',
#  994: 'Hale',
#  995: 'kazanmak',
#  996: 'isyan',
#  997: 'evren',
#  998: 'seyir',
#  999: 'ihtimalî',
#  ...}

# %%
len(kelime2index)
# Out:
# 36559

# %%
import numpy as np

# %%
doc_mat = np.zeros((len(df), len(kelime2index)))

# %%
for i, doc in enumerate(clean_col.values):
    for token in doc:
        token_index = kelime2index[token]
        doc_mat[i][token_index] += 1

# %%
doc_mat[0]
# Out:
# array([0., 2., 1., ..., 0., 0., 0.])

# %%
def cos_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
# sorgular
random.seed(42) # otostopçunun galaksi rehberi
film_indexi = random.randrange(len(df))
film = df.iloc[film_indexi]
film["film adi"], film["ozet ve detaylar"], film["tur"], film["oyuncular"], film["yonetmen"]
# Out:
# ('Gridiron Gang',
#  'Reşit olmamış gençlerin kaldığı bir tutukevinde kamp yöneticisi olan Sean Porter, gençlere futbol sayesinde takım olabilme bilinci ve kendilerine güven duygusu aşılamaya çalışır. Phil Joanou yönetimindeki filmde, Akrep Kral ve The Rundown filmlerinden tanıdık The Rock başrolde.',
#  "['Dramatik komedi']",
#  "['Dwayne Johnson', 'Xzibit', 'L. Scott Caldwell']",
#  "['Phil Joanou']")

# %%
benzerlikler = []
sorgu_film = doc_mat[film_indexi]
for vec in doc_mat:
    benzerlik = cos_sim(sorgu_film, vec)
    benzerlikler.append(benzerlik)

# %%
test_list = [1, 5, 4, 2]
print(np.array(test_list).argsort()[:2])
print((- np.array(test_list)).argsort()[:2])
# Out:
# [0 3]
# [1 2]

# %%
# en yakın 5 film
top5_film_indexleri = (- np.array(benzerlikler)).argsort()[:5]

# %%
for i in top5_film_indexleri:
    film = df.iloc[i]
    print(film["film adi"], film["ozet ve detaylar"], film["tur"], film["oyuncular"], film["yonetmen"])
    print(" - " * 20)
# Out:
# Gridiron Gang Reşit olmamış gençlerin kaldığı bir tutukevinde kamp yöneticisi olan Sean Porter, gençlere futbol sayesinde takım olabilme bilinci ve kendilerine güven duygusu aşılamaya çalışır. Phil Joanou yönetimindeki filmde, Akrep Kral ve The Rundown filmlerinden tanıdık The Rock başrolde. ['Dramatik komedi'] ['Dwayne Johnson', 'Xzibit', 'L. Scott Caldwell'] ['Phil Joanou']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Hayat Ağacı 1950’li yıllarda, Orta Batılı bir aileyi merkezine alan film ailenin en büyük oğlu Jack’in, çocukluk masumiyetinin kaybolmasından başlayarak buruk bir yetişkinlik evresine geçişini konu alıyor. Tam bu geçiş sürecinde de babası (Brad Pitt) ile yaşadığı çalkantılı baba-oğul ilişkisi, öykünün merkezine oturuyor. Jack'in olgunluk hali (Sean Penn) artık modern çağda yolunu yitirmiş bir bireydir. Kaderin varlığını ve çıkmazlarını sorgularken, diğer yandan yaşamın anlamını bulmaya çalışır... Terrence Malick'in 2011 Cannes Film Festivali'nde eleştirmenleri ikiye bölen son filmi Hayat Ağacı, yönetmenin baştan aşağıya imzasını taşıyan bir yapıt. Başrollerde Brad Pitt, Sean Penn ve Jessica Chastain yer alırken, filmin teknik ekibi de özellikle göze çarpıyor. 4 kez Oscar adayı olan görüntü yönetmeni Emmanuel Lubezki, başka bir Brad Pitt filmi olan benjamin Button'ın Tuhaf Hikayesi'ndeki kostüm çalışmasıyla Oscar adaylığı olan Jacqueline West ve yaptığı film müzikleriyle 3 ayrı filmle (The Curious Case Of Benjamın Button, The Queen ve The King’s Speech) Oscar adaylığı olan Alexandre Desplat yapım ekibinde göz çarpan isimler... ['Dram', 'Fantastik'] ['Brad Pitt', 'Jessica Chastain', 'Sean Penn'] ['Terrence Malick']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Büyük Oyun 2010 yılında izleyiciyle buluşan ve gösterime girdiği yılın en ilginç noel filmi alternatiflerinden biri olan korku - komedi kırması Rare Exports ile adından söz ettiren Finlandiyalı yönetmen Jalmari Helander'in yazıp yönettiği son filmi Büyük Oyun; sinemaseverleri hareketli bir aksiyon deneyimine davet ediyor. Dan Smith'in aynı adı taşıyan eserinden beyazperdeye uyarlanan film; eğlenceli bir gençlik filmi olmayı hedefliyor. Ormanda kamp yapmakta olan bir genç, esrarengiz bir bir uçağın kamp alanının yakınlarına düşürülmesi  sonucunda Amerikan Başkanı ile tanışır. Fakat Amerikan Başkanı'nın bu durumda kurtarılması gerekmektedir.  Oskari, kontrolü ele geçirerek Başkan Moore'un kurtarılmasına yardım eder. Başrolde Samuel L. Jackson ve Ray Stevenson gibi isimlerin yer aldığı filmde; Mehmet Kurtuluş'un da rolü bulunuyor. ['Aksiyon', 'Macera'] ['Samuel L. Jackson', 'Onni Tommila', 'Ray Stevenson'] ['Jalmari Helander']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# The Captain İkinci Dünya Savaşı’nın bitmesine az bir zaman kala, genç Willi Herold hayatta kalmak için savaşmaktadır. Asker kaçağı olan Will, şans eseri bir Nazi askerine ait üniforma bulur. Üçüncü Reich'in son, çaresiz haftalarında bulduğu bu terk edilmiş yüzbaşı üniformasını giyip Nazi askerini taklit etmek, Will'in hayatta kalabilmek için en büyük şansıdır. Planını uygulamaya koyan genç adam, sadece sıcak kalmak için çaldığı bu takımın cazibesiyle bezenmiş olduğunu fark eder. Almanlar, onun kim olduğunu sorgulamadan onu lider kabul etmektedir. Kendi kendini yüzbaşı ilan eden Will ile birlikte vahşetin geçit töreni başlar. Will kısa sürede sosyal uygunluğun ve engellenmemiş politik gücün sonuçlarının derin bir hatırlatıcısı haline gelir. Bir üniforma insanın karakterini değiştirebilir mi?
# Eşzamanlı olarak tarihsel bir doktora, kapkara bir komedi ve sosyolojik bir tez çalışması olan "The Captain"ın yönetmen koltuğunda Robert Schwentke oturuyor. Senaryosu da yönetmeninin elinden çıkma olan siyah-beyaz filmin başrollerinde Max Hubacher, Milan Peschel, Frederick Lau yer alıyor. Bari Uluslararası Film Festivali ve San Sebastián Uluslararası Film Festivali'nden ödülle dönen siyah-beyaz film, prömiyerini ise Toronto Uluslararası Film Festivali'nde yaptı. ['Dram', 'Savaş filmi'] ['Max Hubacher', 'Milan Peschel', 'Frederick Lau'] ['Robert Schwentke']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Moonrise Kingdom Samimi ve içten aile hikayeleri ile kendi hatırı sayılır derecede bir hayran kitlesi oluşturan Amerikalı bağımsız filmlerin yönetmeni Wes Anderson'ın yeni filmi Moonrise Kingdom, birbirinden ünlü oyunculardan oluşan kadrosu ile yine yönetmenin kendine has tarzını anlatan bir film. Senaryosunu Wes Anderson ve Roman Coppola'nın birlikte yazdığı film, küçük bir kasabadan kaçan genç aşıkları ve onları bulmak için seferber olan kasaba halkının maceralarını anlatıyor.Moonrise Kingdom, 2012 Cannes Film Festivali'nin açılış filmi. ['Komedi', 'Dram'] ['Bruce Willis', 'Edward Norton', 'Bill Murray'] ['Wes Anderson']
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -

# %%
def print_film(row_index):
    film = df.iloc[row_index]
    adi = film['film adi']
    turu = ", ".join(ast.literal_eval(film['tur']))
    ozet = film['ozet ve detaylar']
    if len(ozet) > 150:
        ozet = ozet[:150] + "..."

    print(f"Film adı: {adi} \nTürü: {turu} \nÖzeti: {ozet} ")

# %%
def benzerlerini_bul(film_adi, benzer_film_sayisi):
    film_indexi = df[df["film adi"] == film_adi].index[0]
    print("Aranan Film:")
    print_film(film_indexi)
    print(" * " * 20)
    print(" * " * 20)

    benzerlikler = []
    sorgu_film = doc_mat[film_indexi]
    for vec in doc_mat:
        benzerlik = cos_sim(sorgu_film, vec)
        benzerlikler.append(benzerlik)
    
    en_benzer_film_indexleri = (- np.array(benzerlikler)).argsort()[:benzer_film_sayisi + 1]
    print("Benzer Filmler:\n")
    for i in en_benzer_film_indexleri[1:]:
        print_film(i)
        print(" - " * 20)
        print(" - " * 20)

# %%
benzerlerini_bul("Yok Artık", 3)
# Out:
# Aranan Film:
# Film adı: Yok Artık
# Türü: Komedi
# Özeti: ‘Taksici Fikret’ bir sabah her zamanki gibi işe gitmek için evden çıkarken ayağını merdivenlerde burkar. Seke seke taksi durağında, arkadaşlarının yan...
#  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
#  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
# Benzer Filmler:
#
# Film adı: Yok Artık! 2
# Türü: Komedi
# Özeti: İlki bir takside geçen serinin 2. filmi ise bir berber dükkanını temel alıyor. Berber Adnan mahallenin dedikodu kazanıdır. Mahalledeki müşterileri hak...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Film adı: Eyvah Karım
# Türü: Komedi
# Özeti: Raşit Çelikezer'in yönetmen koltuğunda oturduğu "Eyvah Karım" filminde, zengin ve sosyetik bir çiftin hikayesi anlatılıyor. Karısının tatile gitmesini...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Film adı: Başlat Ready Player One
# Türü: Bilimkurgu, Aksiyon
# Özeti: Ailesini küçük yaşta kaybeden Wade Watts, gerçek dünyanın sıkıntılarından kaçmak için zamanını The Oasis adlı bir oyun evreninde geçirir. Oyunun milyo...
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -

# %% [markdown]
# İyileştirme için neler yapılabilir? (diğer sütunlar? sütun ağırlıkları?)

# %%
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                                                clean
# 0  [arabesk, unutulmayan, kadın, ses, o, Bergen, ...
# 1  [Çocuk, film, kirpi, Sonic, film, deva, halka,...
# 2  [karmak, büyü, Gellert, Grindelwald, büyü, dün...
# 3  [Aykut, enişte, 2, sevmek, kadın, evlilik, ari...
# 4  [Morbius, hastalık, deva, bulmak, Çalışır, bam...
