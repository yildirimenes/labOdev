# %%
import pandas as pd

# %%
df = pd.read_csv("filmler_clean.csv")

# %%
df.head()
# Out:
#                                       film adi  \
# 0                                       Bergen
# 1                                Kirpi Sonic 2
# 2  Fantastik Canavarlar: Dumbledore'un Sırları
# 3                               Aykut Enişte 2
# 4                                      Morbius
#
#                                     ozet ve detaylar  \
# 0  Arabeskin unutulmayan kadın seslerinden biri o...
# 1  Çocuk filmi \n\n\nKirpi Sonic filminin devam h...
# 2  Karanlık büyücü Gellert Grindelwald, büyücülük...
# 3  Aykut Enişte 2, sevdiği kadınla evlilik arifes...
# 4  Morbius, hastalığına deva bulmaya çalışırken b...
#
#                                   tur  \
# 0              ['Dram', 'Biyografik']
# 1     ['Animasyon', 'Aile', 'Macera']
# 2             ['Fantastik', 'Macera']
# 3                          ['Komedi']
# 4  ['Aksiyon', 'Fantastik', 'Macera']
#
#                                            oyuncular  \
# 0  ['Farah Zeynep Abdullah', 'Erdal Beşikçioğlu',...
# 1              ['Jim Carrey', 'James Marsden', None]
# 2   ['Eddie Redmayne', 'Jude Law', 'Mads Mikkelsen']
# 3  ['Cem Gelinoğlu', 'Melis Babadağ', 'Hakan Yılm...
# 4  ['Jared Leto', 'Matt Smith (XI)', 'Adria Arjona']
#
#                           yonetmen  vizyon tarihi     sure  \
# 0  ['Mehmet Binay', 'Caner Alper']    4 Mart 2022  2s 26dk
# 1                  ['Jeff Fowler']   8 Nisan 2022   2s 2dk
# 2                  ['David Yates']  15 Nisan 2022  2s 22dk
# 3                ['Onur Bilgetay']  3 Aralık 2021  1s 55dk
# 4              ['Daniel Espinosa']   1 Nisan 2022  1s 45dk
#
#                                                clean
# 0  ['arabesk', 'unutmak', 'kadı', 'ses', 'olmak',...
# 1  ['Çocuk', 'film', 'kirpi', 'Sonic', 'film', 'D...
# 2  ['karmak', 'büyü', 'Gellert', 'Grindelwald', '...
# 3  ['Aykut', 'enişte', '2', 'sevmek', 'kadı', 'ev...
# 4  ['Morbius', 'hastalık', 'deva', 'bulmak', 'Çal...

# %%
clean = df["clean"]

# %%
len(clean)
# Out:
# 5261

# %%
word2idx = {}
idx2word = {}

# %%
i = 0
for cell in clean:
    words = cell.split()
    for word in words:
        if word in word2idx:
            continue
        word2idx[word] = i
        idx2word[i] = word
        i += 1

# %%
word2idx
# Out:
# {"['arabesk',": 0,
#  "'unutmak',": 1,
#  "'kadı',": 2,
#  "'ses',": 3,
#  "'olmak',": 4,
#  "'Bergen',": 5,
#  "'in',": 6,
#  "'hayat',": 7,
#  "'anlatmak',": 8,
#  "'film',": 9,
#  "'bilmek',": 10,
#  "'belgin',": 11,
#  "'Ankara',": 12,
#  "'dan',": 13,
#  "'ada',": 14,
#  "'ora',": 15,
#  "'yaşamak',": 16,
#  "'aşkın',": 17,
#  "'art',": 18,
#  "'ebediyet',": 19,
#  "'uzamak',": 20,
#  "'öykü',": 21,
#  "'1959',": 22,
#  "'yıl',": 23,
#  "'mersin',": 24,
#  "'yemek',": 25,
#  "'Çocuk',": 26,
#  "'bir',": 27,
#  "'aile',": 28,
#  "'küçük',": 29,
#  "'çocuk',": 30,
#  "'dünya',": 31,
#  "'gelmek',": 32,
#  "'Anne',": 33,
#  "'baba',": 34,
#  "'boşanmak',": 35,
#  "'kökten',": 36,
#  "'biçim',": 37,
#  "'değişmek',": 38,
#  "'Yaşar',": 39,
#  "'başka',": 40,
#  "'kimse',": 41,
#  "'yok',": 42,
#  "'yoksun',": 43,
#  "'iç',": 44,
#  "'dermek',": 45,
#  "'boş',": 46,
#  "'açar',": 47,
#  "'ötmek',": 48,
#  "'yan',": 49,
#  "'konservatuar',": 50,
#  "'girmek',": 51,
#  "'başarı',": 52,
#  "'katmer',": 53,
#  "'umut',": 54,
#  "'ilk',": 55,
#  "'aşk',": 56,
#  "'Abdullah',": 57,
#  "'tan',": 58,
#  "'ayrılmak',": 59,
#  "'yaramak',": 60,
#  "'almak',": 61,
#  "'am',": 62,
#  "'onmak',": 63,
#  "'Büyük',": 64,
#  "'Gü',": 65,
#  "'yetenek',": 66,
#  "'nın',": 67,
#  "'prestij',": 68,
#  "'mekân',": 69,
#  "'Feyman',": 70,
#  "'kulüp',": 71,
#  "'Te',": 72,
#  "'keşfetmek',": 73,
#  "'parlamak',": 74,
#  "'genç',": 75,
#  "'yıldız',": 76,
#  "'E',": 77,
#  "'dönüşmek',": 78,
#  "'ancak',": 79,
#  "'zaman',": 80,
#  "'koşul',": 81,
#  "'yapılanmak',": 82,
#  "'kontrat',": 83,
#  "'sebebiyle',": 84,
#  "'sürmek',": 85,
#  "'çalışmak',": 86,
#  "'gitmek',": 87,
#  "'müzikhol',": 88,
#  "'sahne',": 89,
#  "'Müzik',": 90,
#  "'tarz',": 91,
#  "'zor',": 92,
#  "'kalmak',": 93,
#  "'daha',": 94,
#  "'sonra',": 95,
#  "'evlenmek',": 96,
#  "'halis',": 97,
#  "'serbest',": 98,
#  "'karşılaşmak',": 99,
#  "'manipülatif',": 100,
#  "'olay',": 101,
#  "'dizi',": 102,
#  "'bulmak',": 103,
#  "'kendi',": 104,
#  "'le',": 105,
#  "'yapmak',": 106,
#  "'evli',": 107,
#  "'düşlemek',": 108,
#  "'tersinmek',": 109,
#  "'i',": 110,
#  "'koparmak',": 111,
#  "'şiddet',": 112,
#  "'dolu',": 113,
#  "'gün',": 114,
#  "'tüm',": 115,
#  "'yalnız',": 116,
#  "'kariyer',": 117,
#  "'güzel',": 118,
#  "'yerinde',": 119,
#  "'kezzap',": 120,
#  "'saldırı',": 121,
#  "'uğramak',": 122,
#  "'göz',": 123,
#  "'kaybetmek',": 124,
#  "'trajedi',": 125,
#  "'rağmen',": 126,
#  "'dönmek',": 127,
#  "'olağanüstü',": 128,
#  "'şarkı',": 129,
#  "'Türki',": 130,
#  "'çap',": 131,
#  "'Şöhret',": 132,
#  "'olur',": 133,
#  "'tehdit',": 134,
#  "'taciz',": 135,
#  "'seyretmek',": 136,
#  "'gerilim',": 137,
#  "'ilişki',": 138,
#  "'Geller',": 139,
#  "'Deva',": 140,
#  "'eder',": 141,
#  "'korku',": 142,
#  "'sonunda',": 143,
#  "'kesin',": 144,
#  "'ten',": 145,
#  "'kurtulmak',": 146,
#  "'düşünmek',": 147,
#  "'yolcu',": 148,
#  "'silâh',": 149,
#  "'ağır',": 150,
#  "'yara',": 151,
#  "'henüz',": 152,
#  "'30',": 153,
#  "'yaş',": 154,
#  "'ölmek',": 155,
#  "'kurban',": 156,
#  "'arabesk',": 157,
#  "'kraliçe',": 158,
#  "'insan',": 159,
#  "'kalp',": 160,
#  "'kazımak',": 161,
#  "'Dram',": 162,
#  "'Biyografik',": 163,
#  "'Farah": 164,
#  'Zeynep': 165,
#  "Abdullah',": 166,
#  "'Erdal": 167,
#  "Beşikçioğlu',": 168,
#  "'Tilbe": 169,
#  "Saran',": 170,
#  "'Mehmet": 171,
#  "Binay',": 172,
#  "'Caner": 173,
#  "Alper']": 174,
#  "['Çocuk',": 175,
#  "'kirpi',": 176,
#  "'Sonic',": 177,
#  "'halka',": 178,
#  "'yapım',": 179,
#  "'atılmak',": 180,
#  "'macera',": 181,
#  "'konu',": 182,
#  "'etmek',": 183,
#  "'Green',": 184,
#  "'Hills',": 185,
#  "'yerleşmek',": 186,
#  "'tek',": 187,
#  "'istek',": 188,
#  "'gerçek',": 189,
#  "'kahraman',": 190,
#  "'gerekmek',": 191,
#  "'özellik',": 192,
#  "'sahip',": 193,
#  "'kanıtlamak',": 194,
#  "'sınav',": 195,
#  "'Dr',": 196,
#  "'Robotnik',": 197,
#  "'ortak',": 198,
#  "'Knuckes',": 199,
#  "'medeniyet',": 200,
#  "'zümrüt',": 201,
#  "'aramak',": 202,
#  "'geri',": 203,
#  "'dönme',": 204,
#  "'başlamak',": 205,
#  "'yanlış',": 206,
#  "'el',": 207,
#  "'geçmek',": 208,
#  "'engellemek',": 209,
#  "'yardımcı',": 210,
#  "'Tails',": 211,
#  "'çıkmak',": 212,
#  "'Animasyon',": 213,
#  "'Aile',": 214,
#  "'Macera',": 215,
#  "'Jim": 216,
#  "Carrey',": 217,
#  "'James": 218,
#  "Marsden',": 219,
#  'None,': 220,
#  "'Jeff": 221,
#  "Fowler']": 222,
#  "['karmak',": 223,
#  "'büyü',": 224,
#  "'Gellert',": 225,
#  "'Grindelwald',": 226,
#  "'kontrol',": 227,
#  "'elemek',": 228,
#  "'geçirmek',": 229,
#  "'hareket',": 230,
#  "'bun',": 231,
#  "'öğrenmek',": 232,
#  "'profesör',": 233,
#  "'Albus',": 234,
#  "'Dumbledore',": 235,
#  "'önce',": 236,
#  "'o',": 237,
#  "'baş',": 238,
#  "'durmak',": 239,
#  "'Çalışır',": 240,
#  "'başarmak',": 241,
#  "'ara',": 242,
#  "'cadı',": 243,
#  "'cesur',": 244,
#  "'Muggle',": 245,
#  "'fırın',": 246,
#  "'oluşmak',": 247,
#  "'ekip',": 248,
#  "'yönetim',": 249,
#  "'Büyüzoolog',": 250,
#  "'Newt',": 251,
#  "'Scamander',": 252,
#  "'A',": 253,
#  "'Emanet',": 254,
#  "'tehlike',": 255,
#  "'görev',": 256,
#  "'üst',": 257,
#  "'canavar',": 258,
#  "'mücadele',": 259,
#  "'sayı',": 260,
#  "'artmak',": 261,
#  "'un',": 262,
#  "'mürit',": 263,
#  "'savaşmak',": 264,
#  "'risk',": 265,
#  "'karşı',": 266,
#  "'Kadar',": 267,
#  "'kenar',": 268,
#  "'MJ',": 508,
#  "'Ned',": 509,
#  "'olumsuz',": 510,
#  "'etkilemek',": 511,
#  "'şahit',": 512,
#  "'üniversite',": 513,
#  "'şans',": 514,
#  "'seyir',": 515,
#  "'yakarmak',": 516,
#  "'nü',": 517,
#  "'May',": 518,
#  "'Happy',": 519,
#  "'hatırlamak',": 520,
#  "'kişi',": 521,
#  "'parametre',": 522,
#  "'Tom": 523,
#  "Holland',": 524,
#  "'Zendaya',": 525,
#  "'Benedict": 526,
#  "Cumberbatch',": 527,
#  "'Jon": 528,
#  "Watts']": 529,
#  "['The',": 530,
#  "'batman',": 531,
#  "'suçlu',": 532,
#  "'salmak',": 533,
#  "'Riddler',": 534,
#  "'isim',": 535,
#  "'ser',": 536,
#  "'katil',": 537,
#  "'dolaşmak',": 538,
#  "'Bruce',": 539,
#  "'Wayne',": 540,
#  "'Gotham',": 541,
#  "'City',": 542,
#  "'karmak',": 543,
#  "'kalbî',": 544,
#  "'sürüklemek',": 545,
#  "'gizem',": 546,
#  "'şehir',": 547,
#  "'seçkin',": 548,
#  "'Hedef',": 549,
#  "'sadist',": 550,
#  "'hain',": 551,
#  "'iz',": 552,
#  "'sürme',": 553,
#  "'İpuçlarınını',": 554,
#  "'peşin',": 555,
#  "'yol',": 556,
#  "'süreç',": 557,
#  "'Catwoman',": 558,
#  "'Selina',": 559,
#  "'Kyle',": 560,
#  "'penguen',": 561,
#  "'Oswald',": 562,
#  "'Cobblepot',": 563,
#  "'Carmine',": 564,
#  "'Falcone',": 565,
#  "'karakter',": 566,
#  "'kesişmek',": 567,
#  "'kurmak',": 568,
#  "'yardım',": 569,
#  "'maske',": 570,
#  "'düşürmek',": 571,
#  "'Ni',": 572,
#  "'huzur',": 573,
#  "'kavuşmak',": 574,
#  "'girişmek',": 575,
#  "'Polisiye',": 576,
#  "'Gerilim',": 577,
#  "'Robert": 578,
#  "Pattinson',": 579,
#  "'Zoë": 580,
#  "Kravitz',": 581,
#  "'Paul": 582,
#  "Dano',": 583,
#  "Reeves']": 584,
#  "['zaman',": 585,
#  "'taşımak',": 586,
#  "'yer',": 587,
#  "'Sherlock',": 588,
#  "'kurgu',": 589,
#  "'dedektif',": 590,
#  "'rol',": 591,
#  "'ün',": 592,
#  "'Wikileaks',": 593,
#  "'beşinci',": 594,
#  "'Kuvvet',": 595,
#  "'bilinmez',": 596,
#  "'doğru',": 597,
#  "'star',": 598,
#  "'Trek',": 599,
#  "'The',": 600,
#  "'Imitation',": 601,
#  "'Game',": 602,
#  "'Enigma',": 603,
#  "'Benedict',": 604,
#  "'Cumberbatch',": 605,
#  "'yönetmen',": 606,
#  "'Scott',": 607,
#  "'Derrickson',": 608,
#  "'kamera',": 609,
#  "'Arkas',": 610,
#  "'Sâdık',": 611,
#  "'usta',": 612,
#  "'Wong',": 613,
#  "'Elizabeth": 614,
#  "Olsen',": 615,
#  "'Rachel": 616,
#  "McAdams',": 617,
#  "'Sam": 618,
#  "Raimi']": 619,
#  "['Dilberay',": 620,
#  "'2019',": 621,
#  "'veda',": 622,
#  "'dilber',": 623,
#  "'Ay',": 624,
#  "'Kahramanmaraş',": 625,
#  "'Ta',": 626,
#  "'sekiz',": 627,
#  "'çadır',": 628,
#  "'par',": 629,
#  "'karşılık',": 630,
#  "'satmak',": 631,
#  "'tutku',": 632,
#  "'şark',": 633,
#  "'söylemekti',": 634,
#  "'yüz',": 635,
#  "'dayak',": 636,
#  "'işkence',": 637,
#  "'Çek',": 638,
#  "'acı',": 639,
#  "'se',": 640,
#  "'Güç',": 641,
#  "'ad',": 642,
#  "'at',": 643,
#  "'boyun',": 644,
#  "'zirve',": 645,
#  "'dip',": 646,
#  "'vurmak',": 647,
#  "'düşmek',": 648,
#  "'kuyu',": 649,
#  "'söylemek',": 650,
#  "'çıktı',": 651,
#  "'Büşra": 652,
#  "Pekin',": 653,
#  "'Zeliha": 654,
#  "Kendirci',": 655,
#  "'Nursel": 656,
#  "Köse',": 657,
#  "'Ketche']": 658,
#  "'Doru',": 659,
#  "'orman',": 660,
#  "'kurtarmak',": 661,
#  "'Karatay',": 662,
#  "'Alaca',": 663,
#  "'hayvan',": 664,
#  "'sirk',": 665,
#  "'üzeri',": 666,
#  "'yakmak',": 667,
#  "'yı',": 668,
#  "'zeki',": 669,
#  "'sayesinde',": 670,
#  "'kurtaran',": 671,
#  "'sürpriz',": 672,
#  "'kaçmak',": 673,
#  "'bebek',": 674,
#  "'şempanze',": 675,
#  "'Şöbi',": 676,
#  "'Arkın": 677,
#  "Aktaç']": 678,
#  "['25',": 679,
#  "'gele',": 680,
#  "'gelecek',": 681,
#  "'gerçekten',": 682,
#  "'Will',": 683,
#  "'Salas',": 684,
#  "'Justin',": 685,
#  "'Timberlake',": 686,
#  "'hata',": 687,
#  "'sonuç',": 688,
#  "'cinayet',": 689,
#  "'hüküm',": 690,
#  "'giymek',": 691,
#  "'hapishane',": 692,
#  "'şan',": 693,
#  "'sistem',": 694,
#  "'çökermek',": 695,
#  "'zira',": 696,
#  "'rahatlıkla',": 697,
#  "'alınmak',": 698,
#  "'Zengi',": 699,
#  "'son',": 700,
#  "'kalarak',": 701,
#  "'fakir',": 702,
#  "'üstelik',": 703,
#  "'ek',": 704,
#  "'Güçs',": 705,
#  "'üzmek',": 706,
#  "'sadece',": 707,
#  "'kalabilmek',": 708,
#  "'dilemek',": 709,
#  "'ödünç',": 710,
#  "'hat',": 711,
#  "'bazen',": 712,
#  "'çalmak',": 713,
#  "'yoz',": 714,
#  "'kaldırmak',": 715,
#  "'başrol',": 716,
#  "'Döne',": 717,
#  "'sinema',": 718,
#  "'yönelmek',": 719,
#  "'Scarlett',": 720,
#  "'Johansson',": 721,
#  "'Anı',": 722,
#  "'Amanda',": 723,
#  "'Seyfried',": 724,
#  "'oyun',": 725,
#  "'kadro',": 726,
#  "'Olivia',": 727,
#  "'Wild',": 728,
#  "'Alex',": 729,
#  "'Pettyfer',": 730,
#  "'Cillian',": 731,
#  "'Murphy',": 732,
#  "'Gattaca',": 733,
#  "'S1m0ne',": 734,
#  "'Lord',": 735,
#  "'of',": 736,
#  "'War',": 737,
#  "'yazmak',": 738,
#  "'yönetmek',": 739,
#  "'Truman',": 740,
#  "'Show',": 741,
#  "'terminal',": 742,
#  "'Marcia',": 861,
#  "'Gay',": 862,
#  "'Harden',": 863,
#  "'Bella',": 864,
#  "'Heathcote',": 865,
#  "'yermek',": 866,
#  "'Erotik',": 867,
#  "'Bella": 868,
#  "Heathcote',": 869,
#  "Foley']": 870,
#  "['Day',": 871,
#  "'sevi',": 872,
#  "'kabadayı',": 873,
#  "'adalet',": 874,
#  "'duygu',": 875,
#  "'cesaret',": 876,
#  "'merhamet',": 877,
#  "'haylaz',": 878,
#  "'bıkmak',": 879,
#  "'tarafından',": 880,
#  "'köy',": 881,
#  "'İstanbul',": 882,
#  "'göndermek',": 883,
#  "'kahve',": 884,
#  "'Seyfi',": 885,
#  "'yanında',": 886,
#  "'ailemine',": 887,
#  "'Yükselir',": 888,
#  "'Ufuk": 889,
#  "Bayraktar',": 890,
#  "'Gizem": 891,
#  "Karaca',": 892,
#  "'Ahmet": 893,
#  "Varlı',": 894,
#  "'Uğur": 895,
#  "Bayraktar']": 896,
#  "['kaymak',": 897,
#  "'yazar',": 898,
#  "'Loretta',": 899,
#  "'Sage',": 900,
#  "'inziva',": 901,
#  "'çekilmek',": 902,
#  "'Dash',": 903,
#  "'canlanmak',": 904,
#  "'adamak',": 905,
#  "'kapak',": 906,
#  "'model',": 907,
#  "'popüler',": 908,
#  "'egzotik',": 909,
#  "'hak',": 910,
#  "'kitap',": 911,
#  "'tanıtım',": 912,
#  "'turne',": 913,
#  "'eksantrik',": 914,
#  "'milyarder',": 915,
#  "'antik',": 916,
#  "'hazine',": 917,
#  "'vakit',": 918,
#  "'an',": 919,
#  "'Sandra": 920,
#  "Bullock',": 921,
#  "'Channing": 922,
#  "Tatum',": 923,
#  "Radcliffe',": 924,
#  "'Aaron": 925,
#  "Nee',": 926,
#  "'Adam": 927,
#  "Nee']": 928,
#  "['6',": 929,
#  "'uygun',": 930,
#  "'yetkili',": 931,
#  "'kurtulup',": 932,
#  "'şeytanî',": 933,
#  "'bulunmak',": 934,
#  "'yüzük',": 935,
#  "'hükümet',": 936,
#  "'yakalamak',": 937,
#  "'devlet',": 938,
#  "'Eggman',": 939,
#  "'kasap',": 940,
#  "'şerif',": 941,
#  "'Tom',": 942,
#  "'Wachowski',": 943,
#  "['kuzey',": 944,
#  "'intikam',": 945,
#  "'Viking',": 946,
#  "'prens',": 947,
#  "'kral',": 948,
#  "'Aurvandil',": 949,
#  "'imparator',": 950,
#  "'oğul',": 951,
#  "'Amleth',": 952,
#  "'devretmek',": 953,
#  "'üveymek',": 954,
#  "'Fjölnir',": 955,
#  "'taht',": 956,
#  "'amca',": 957,
#  "'Gudrun',": 958,
#  "'alacak',": 959,
#  "'kurtaracağına',": 960,
#  "'yemin',": 961,
#  "'Slav',": 962,
#  "'ak',": 963,
#  "'savaş',": 964,
#  "'kâhin',": 965,
#  "'tutmak',": 966,
#  "'Tarihi',": 967,
#  "'Alexander": 968,
#  "Skarsgård',": 969,
#  "'Nicole": 970,
#  "Kidman',": 971,
#  "'Claes": 972,
#  "Bang',": 973,
#  "Eggers']": 974,
#  "['Uzak',": 975,
#  "'Dune',": 976,
#  "'çöl',": 977,
#  "'gezegen',": 978,
#  "'Arrakis',": 979,
#  "'Paul',": 980,
#  "'Atreides',": 981,
#  "'galâksi',": 982,
#  "'fark',": 983,
#  "'rakip',": 984,
#  "'feodal',": 985,
#  "'Değer',": 986,
#  "'kaynak',": 987,
#  "'üremek',": 988,
#  "'asil',": 989,
#  "'derece',": 990,
#  "'talep',": 991,
#  "'baharat',": 992,
#  "'veri',": 993,
#  "'Yüksek',": 994,
#  "'bilinç',": 995,
#  "'uzun',": 996,
#  "'süre',": 997,
#  "'sunmak',": 998,
#  "'ciddi',": 999,
#  ...}

# %%
len(word2idx)
# Out:
# 41269

# %%
import numpy as np

# %%
film_sayisi = len(clean)
vocab_size = len(word2idx)

# %%
filmler = np.zeros((film_sayisi, vocab_size))

# %%
filmler.shape
# Out:
# (5261, 41269)

# %%
for i, cell in enumerate(clean):
    words = cell.split()
    for word in words:
        wordIndex = word2idx[word]
        filmler[i][wordIndex] += 1

# %%
filmler[7][:10]
# Out:
# array([0., 0., 0., 0., 1., 0., 1., 2., 0., 0.])

# %%
doc_frequencies = {}

# %%
# 1 - 5 dk sürebilir 
for word in word2idx:
    doc_count = 0
    for film in clean:
        if word in film:
            doc_count += 1
    
    doc_frequencies[word] = doc_count

# %%
sorted_frequencies = sorted(doc_frequencies, key=doc_frequencies.get, reverse=True)

# %%
for word in sorted_frequencies[:10]:
    print(word, doc_frequencies[word])
# Out:
# ', 5261
# '] 5254
# 'bir', 5121
# la 5035
# de 4782
# da 4467
# 'o', 3754
# 'film', 3351
# film', 3351
# 'olmak', 2812

# %%
for word in sorted_frequencies[150:160]:
    print(word, doc_frequencies[word])
# Out:
# 'koltuk', 551
# 'şekil', 551
# 'Ni 547
# 'i', 543
# 'yaşayan', 543
# 'art', 539
# 'ölmek', 538
# 'vermek', 538
# 'biri', 537
# 'macera', 534

# %%
for word in sorted_frequencies[-10:]:
    print(word, doc_frequencies[word])
# Out:
# 'menü', 1
# 'kaçırıldığında', 1
# 'labaratuarla', 1
# 'Labaratuarda', 1
# '1621', 1
# Hayward'] 1
# ['Neruda', 1
# 'Peluchonneau', 1
# 'şairane', 1
# 'bitecekmiş', 1

# %%
# 1 - 5 dk sürebilir
filmler_tf_idf = np.zeros((film_sayisi, vocab_size))
film_sayisi = len(clean)

for i, film in enumerate(filmler):
    if i % 1000 == 0:
        print(f"{i} inci film işleniyor...")
    for j, tf in enumerate(film):
        idf = 0
        if tf > 0:
            idf = np.log(film_sayisi / (doc_frequencies[idx2word[j]] + 1)) + 1
        tf_idf_score = tf * idf
        filmler_tf_idf[i][j] = tf_idf_score
# Out:
# 0 inci film işleniyor...
# 1000 inci film işleniyor...
# 2000 inci film işleniyor...
# 3000 inci film işleniyor...
# 4000 inci film işleniyor...
# 5000 inci film işleniyor...

# %%
print(filmler_tf_idf[0][:10])
print(filmler[0][:10])
# Out:
# [ 8.87492922  5.69687539  2.71161442  4.97295655  6.50427837 81.81782041
#   8.17190262  7.44945431  9.68137717  1.45076394]
# [ 1.  1.  1.  1.  4. 10.  4.  4.  2.  1.]

# %%
def cos_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
def film_2_str(row_index):
    film = df.iloc[row_index]
    adi = film['film adi']
    turu = film['tur']
    ozet = film['ozet ve detaylar']
    if len(ozet) > 150:
        ozet = ozet[:150] + "..."

    return f"Film adı: {adi} \nTürü: {turu} \nÖzeti: {ozet}"

# %%
print(film_2_str(0))
# Out:
# Film adı: Bergen
# Türü: ['Dram', 'Biyografik']
# Özeti: Arabeskin unutulmayan kadın seslerinden biri olan Bergen'in hayatını anlatan filmde, Bergen olarak bilinen Belgin'in Ankara'dan Adana'ya, oradan da ya...

# %%
def most_similar_films(film_adi, benzer_film_sayisi):
    film_indexi = df[df["film adi"] == film_adi].index[0]
    print("Aranan Film:")
    print(film_2_str(film_indexi))
    print()
    print("* " * 30)
    print()

    benzerlikler = []
    sorgu_film = filmler_tf_idf[film_indexi]
    for vec in filmler_tf_idf:
        benzerlik = cos_sim(sorgu_film, vec)
        benzerlikler.append(benzerlik)
    
    en_benzer_film_indexleri = (- np.array(benzerlikler)).argsort()[:benzer_film_sayisi + 1]
    print("Benzer Filmler:\n")
    for i, film_idx in enumerate(en_benzer_film_indexleri[1:]):
        print(str(i+1) + ") " + film_2_str(film_idx))
        print()
        print("- " * 20)
        print()

# %%
df.iloc[:10]["film adi"]
# Out:
# 0                                         Bergen
# 1                                  Kirpi Sonic 2
# 2    Fantastik Canavarlar: Dumbledore'un Sırları
# 3                                 Aykut Enişte 2
# 4                                        Morbius
# 5                                        Kırmızı
# 6                                            Kar
# 7                    Kesişme: İyi ki Varsın Eren
# 8                     Örümcek-Adam Eve Dönüş Yok
# 9                                     The Batman
# Name: film adi, dtype: object

# %%
most_similar_films("Yok Artık", 5)
# Out:
# Aranan Film:
# Film adı: Yok Artık
# Türü: ['Komedi']
# Özeti: ‘Taksici Fikret’ bir sabah her zamanki gibi işe gitmek için evden çıkarken ayağını merdivenlerde burkar. Seke seke taksi durağında, arkadaşlarının yan...
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# Benzer Filmler:
#
# 1) Film adı: Yok Artık! 2
# Türü: ['Komedi']
# Özeti: İlki bir takside geçen serinin 2. filmi ise bir berber dükkanını temel alıyor. Berber Adnan mahallenin dedikodu kazanıdır. Mahalledeki müşterileri hak...
#
# - - - - - - - - - - - - - - - - - - - -
#
# 2) Film adı: Tatlım Tatlım
# Türü: ['Romantik', 'Komedi']
# Özeti: Yılmaz Erdoğan'ın yazdığı ve Demet Akbağ ile senelerce kapalı gişe oynadıkları Haybeden Gerçeküstü Aşk'ın film uyarlaması olan filmde aynı partide tan...
#
# - - - - - - - - - - - - - - - - - - - -
#
# 3) Film adı: Azubel
# Türü: ['Korku']
# Özeti: Azubel, korkunç durumlarla karşılaştıkları evden kurtumaya çalışan bir çiftin hikayesini konu ediyor. Bir psikolog olan Serkan, Youtube üzerinden sean...
#
# - - - - - - - - - - - - - - - - - - - -
#
# 4) Film adı: Türk İşi Dondurma
# Türü: ['Tarihi', 'Dram', 'Macera']
# Özeti: Turkish'i Dondurma, Çanakkale Savaşı sırasında Avustralya'da yaşayan iki Türk'ün ülkeleri için verdikleri mücadeleyi konu ediyor. Avustralya’da yaşaya...
#
# - - - - - - - - - - - - - - - - - - - -
#
# 5) Film adı: Bende Kal
# Türü: ['Komedi']
# Özeti: Bende Kal, Fikret ve arkadaşlarının peşlerine düşen mafya ile mücadelesini konu diyor. Babadan kalma berber dükkanını işleten Fikret, her tıraş sonras...
#
# - - - - - - - - - - - - - - - - - - - -
